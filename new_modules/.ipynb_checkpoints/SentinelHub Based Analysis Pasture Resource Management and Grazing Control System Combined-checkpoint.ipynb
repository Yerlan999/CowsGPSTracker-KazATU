# %% [markdown]
# # Импортирование необходимых библиотек

# %%
from sentinelhub import SHConfig
from sentinelhub import SentinelHubCatalog

import datetime, os, csv, math, random
from math import ceil
import matplotlib.pyplot as plt
import numpy as np
from shapely.ops import unary_union
from fiona.drvsupport import supported_drivers
import geopandas as gpd
from matplotlib.path import Path
from shapely.geometry import Polygon
import earthpy.spatial as es
import earthpy.plot as ep
import numpy.ma as ma
from scipy.stats.mstats import gmean, hmean
import pandas as pd
import seaborn as sns
from functools import reduce
from matplotlib.colors import LinearSegmentedColormap

from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sentinelhub import (
    CRS,
    BBox,
    DataCollection,
    DownloadRequest,
    MimeType,
    MosaickingOrder,
    SentinelHubDownloadClient,
    SentinelHubRequest,
    bbox_to_dimensions,
    filter_times
)

# The following is not a package. It is a file utils.py which should be in the same folder as this notebook.
from utils import plot_image

colors = ['tomato', 'navy', 'MediumSpringGreen', 'lightblue', 'orange', 'blue',
          'maroon', 'purple', 'yellow', 'olive', 'brown', 'cyan']

import csv, json, codecs, sys
import urllib.request
import urllib.error
import pandas as pd

import requests
from bs4 import BeautifulSoup

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
sns.set()

# %% [markdown]
# # Подключение к аккаунту Sentinel Hub

# %%
CLIENT_ID = os.getenv('CLIENT_ID')
CLIENT_SECRET = os.environ.get('CLIENT_SECRET')

config = SHConfig()

if CLIENT_ID and CLIENT_SECRET:
    config.sh_client_id = CLIENT_ID
    config.sh_client_secret = CLIENT_SECRET

if not config.sh_client_id or not config.sh_client_secret:
    print("Warning! To use Process API, please provide the credentials (OAuth client ID and client secret).")

# %%
catalog = SentinelHubCatalog(config=config)
# catalog.get_info()

# %% [markdown]
# # Получение координат экспериментального пастбища

# %%
supported_drivers['KML'] = 'rw'
pasture_df = gpd.read_file('pasture.kml', driver='KML')

all_zagons = []
for zagon in range(len(pasture_df.index)):
    all_zagons.append(pasture_df.loc[zagon].geometry)
    
merged_zagons = unary_union(all_zagons)

gpd.GeoSeries([merged_zagons]).boundary.plot()
plt.show()

# %%
x_min, y_min, x_max, y_max = merged_zagons.bounds
pasture_coords_wgs84 = (x_min, y_min, x_max, y_max)

# %% [markdown]
# # Отправка запросов и получение снимков

# %%
resolution = 10
pasture_bbox = BBox(bbox=pasture_coords_wgs84, crs=CRS.WGS84)
pasture_size = bbox_to_dimensions(pasture_bbox, resolution=resolution)

print(f"Image shape at {resolution} m resolution: {pasture_size} pixels")
# Out:
# Image shape at 10 m resolution: (157, 78) pixels

# %% [markdown]
# # Доступные базы данных (Спутиковые базы!!!)

# %%
print("Supported DataCollections:\n")
for collection in DataCollection.get_available_collections():
    print(collection)
# Out:
# Supported DataCollections:
#
# DataCollection.SENTINEL2_L1C
# DataCollection.SENTINEL2_L2A
# DataCollection.SENTINEL1
# DataCollection.SENTINEL1_IW
# DataCollection.SENTINEL1_IW_ASC
# DataCollection.SENTINEL1_IW_DES
# DataCollection.SENTINEL1_EW
# DataCollection.SENTINEL1_EW_ASC
# DataCollection.SENTINEL1_EW_DES
# DataCollection.SENTINEL1_EW_SH
# DataCollection.SENTINEL1_EW_SH_ASC
# DataCollection.SENTINEL1_EW_SH_DES
# DataCollection.DEM
# DataCollection.DEM_MAPZEN
# DataCollection.DEM_COPERNICUS_30
# DataCollection.DEM_COPERNICUS_90
# DataCollection.MODIS
# DataCollection.LANDSAT_MSS_L1
# DataCollection.LANDSAT_TM_L1
# DataCollection.LANDSAT_TM_L2
# DataCollection.LANDSAT_ETM_L1
# DataCollection.LANDSAT_ETM_L2
# DataCollection.LANDSAT_OT_L1
# DataCollection.LANDSAT_OT_L2
# DataCollection.SENTINEL5P
# DataCollection.SENTINEL3_OLCI
# DataCollection.SENTINEL3_SLSTR
# DataCollection.HARMONIZED_LANDSAT_SENTINEL

# %% [markdown]
# # Выбор одной из доступных баз данных

# %%
data_collection = DataCollection.SENTINEL2_L2A
bands_dict = dict([(band.name, i) for i, band in enumerate(data_collection.bands)])
aux_data_dict = dict([(band, i) for i, band in enumerate(["sunZenithAngles","sunAzimuthAngles","viewZenithMean","viewAzimuthMean"])])

# %% [markdown]
# # Составление запросов

# %%
evalscript_all_bands = """
    //VERSION=3
    function setup() {{
        return {{
            input: [{{
                bands: [{BANDS}],
                units: "DN"
            }}],
            output: {{
                bands: {COUNT},
                sampleType: "FLOAT32"
            }}
        }};
    }}

    function evaluatePixel(sample) {{
        return [{SAMPLE}];
    }}
"""
template1 = ""; template2 = ""
for band in bands_dict.keys(): 
    template1 += f'"{band}", '; 
    template2 += f'sample.{band}, ';
settings = {"BANDS": template1, "SAMPLE": template2, "COUNT": str(len(bands_dict))}
evalscript_all_bands = evalscript_all_bands.format(**settings)

# %%
evalscript_aux_data = """
    //VERSION=3

    function setup() {{
        return {{
            input: [{{
                bands: [{BANDS}],
                units: "DEGREES"
            }}],
            output: {{
                bands: {COUNT},
                sampleType: "FLOAT32"
            }}
        }};
    }}

    function evaluatePixel(sample) {{
        return [{SAMPLE}];
    }}
"""
template1 = ""; template2 = ""
for band in aux_data_dict.keys(): 
    template1 += f'"{band}", '; 
    template2 += f'sample.{band}, ';
settings = {"BANDS": template1, "SAMPLE": template2, "COUNT": str(len(aux_data_dict))}
evalscript_aux_data = evalscript_aux_data.format(**settings)

# %% [markdown]
# # Снимки на даты (с 01.05.2023 по 31.08.2023)

# %%
time_interval = "2021-05-01", "2021-08-31"

search_iterator = catalog.search(
    data_collection,
    bbox=pasture_bbox,
    time=time_interval,
    filter="eo:cloud_cover <= 100",
    fields={"include": ["id", "properties.datetime", "properties.eo:cloud_cover"], "exclude": []},
)

results = list(search_iterator)
print("Total number of results:", len(results))

# results
# Out:
# Total number of results: 49

# %%
time_difference = datetime.timedelta(hours=1)

all_timestamps = search_iterator.get_timestamps()
unique_acquisitions = filter_times(all_timestamps, time_difference)

# unique_acquisitions

# %%
all_bands_process_requests = []

for timestamp in unique_acquisitions:
    request = SentinelHubRequest(
        evalscript=evalscript_all_bands,
        input_data=[
            SentinelHubRequest.input_data(
                data_collection=data_collection,
                time_interval=(timestamp - time_difference, timestamp + time_difference),
            )
        ],
        responses=[SentinelHubRequest.output_response("default", MimeType.TIFF)],
        bbox=pasture_bbox,
        size=pasture_size,
        config=config,
    )
    all_bands_process_requests.append(request)

# %%
aux_data_process_requests = []

for timestamp in unique_acquisitions:
    request = SentinelHubRequest(
        evalscript=evalscript_aux_data,
        input_data=[
            SentinelHubRequest.input_data(
                data_collection=data_collection,
                time_interval=(timestamp - time_difference, timestamp + time_difference),
            )
        ],
        responses=[SentinelHubRequest.output_response("default", MimeType.TIFF)],
        bbox=pasture_bbox,
        size=pasture_size,
        config=config,
    )
    aux_data_process_requests.append(request)

# %%
# %%time

client = SentinelHubDownloadClient(config=config)
all_bands_download_requests = [request.download_list[0] for request in all_bands_process_requests]
all_bands_data = client.download(all_bands_download_requests)
# Out:
# Wall time: 16.2 s

# %%
# %%time

client = SentinelHubDownloadClient(config=config)
aux_data_download_requests = [request.download_list[0] for request in aux_data_process_requests]
aux_data = client.download(aux_data_download_requests)
# Out:
# Wall time: 5.91 s

# %% [markdown]
# # Составление маски пастбища

# %%
aoi_height, aoi_width = pasture_size[-1], pasture_size[0]

# %%
masks = []
pasture_edges = []
for zagon in range(len(pasture_df)-1):
    polygon=[]

    for coords in pasture_df.loc[zagon].geometry.exterior.coords:

        x = int(np.interp(coords[0], [x_min, x_max], [0, aoi_width]))
        y = int(np.interp(coords[1], [y_min, y_max], [aoi_height, 0]))

        polygon.append((y, x))
        
    poly_path=Path(polygon)
    x, y = np.mgrid[:aoi_height, :aoi_width]
    coors=np.hstack((x.reshape(-1, 1), y.reshape(-1,1)))
    
    pasture_edges.append(Polygon(polygon))
    
    mask = ~poly_path.contains_points(coors)
    masks.append(mask)
    
combined_mask = reduce(np.logical_and, masks)

# %% [markdown]
# # Маска для загона №1

# %%
plt.imshow(masks[0].reshape(aoi_height, aoi_width))
plt.show()

# %% [markdown]
# # Маска для пастбища

# %%
plt.imshow(combined_mask.reshape(aoi_height, aoi_width))
plt.show()

# %% [markdown]
# # Объявление вспомогательных функции

# %%
def normalize(band):
    band_min, band_max = (band.min(), band.max())
    return ((band - band_min)/((band_max - band_min)))

def brighten(band):
    alpha=0.13
    beta=0
    return np.clip(alpha*band+beta, 0, 255)

def Kcluster(matrix, n_clusters=3):
#     scaler = MinMaxScaler(); matrix = scaler.fit_transform(matrix);
#     scaler = StandardScaler(); matrix = scaler.fit_transform(matrix);

    flattened_matrix = matrix.flatten()

    kmeans = KMeans(n_clusters=n_clusters, random_state=45)
    kmeans.fit(flattened_matrix.reshape(-1, 1))

    cluster_labels = kmeans.labels_
    result_index = cluster_labels.reshape(matrix.shape)
    result_index = ma.masked_array(result_index, mask=combined_mask.reshape(aoi_height, aoi_width))

    return ~(result_index == 0), ~(result_index == 1), ~(result_index == 2) 

def get_only_pasture(index):
    only_pasture = ma.masked_array(ma.masked_array((index), mask=np.isinf((index)) | np.isnan((index))), mask=combined_mask.reshape(aoi_height, aoi_width))
    return only_pasture

def get_only_zagon(index, zagon):
    only_pasture = ma.masked_array(ma.masked_array((index), mask=np.isinf((index)) | np.isnan((index))), mask=masks[zagon-1].reshape(aoi_height, aoi_width))
    return only_pasture

def mean(index):
    return float(index.mean())

def median(index):
    return float(ma.median(index))


def show_real_pasture():
    
    fig, ax = plt.subplots(figsize=(12, 6))
    for zagon in range(len(pasture_df)-1):
        ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])
    ep.plot_rgb(np.stack([RED, GREEN, BLUE]), ax=ax, title=general_info, figsize=(12, 6))
    plt.show()    

    
def show_pasture_index(test_meet, lower_bound, upper_bound, show_hists=True, save_excel=False):
    
    fig, ax = plt.subplots(figsize=(12, 12))
    for zagon in range(len(pasture_df)-1):

        ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])

    header = input_text
    precision = 4
    # print(f"Макс: {round(float(test_meet.max()),precision)} || Мин: {round(float(test_meet.min()),precision)} || Сред: {round(float(test_meet.mean()),precision)} || Сумм: {round(float(test_meet.sum()),precision)}")
    ep.plot_bands(test_meet, title=f"{header} {general_info}", ax=ax, cmap="bwr", cols=1, vmin=lower_bound, vmax=upper_bound, figsize=(10, 14))
    plt.show()

    test_index_masked_array = []
    for i, mask in enumerate(masks):
        mx = ma.masked_array(test_meet, mask=mask.reshape(aoi_height, aoi_width))
        test_index_masked_array.append(mx)

    summary_data = []
    for i, zagon in enumerate(test_index_masked_array):
        summary_data.append([f"№{i+1}", round(zagon.sum(),precision), round(zagon.mean(),precision), round(ma.median(zagon),precision), round(zagon.max(),precision), round(zagon.min(),precision)])


    styles = [
        {'selector': '',
         'props': [('border', '2px solid #000'), ('border-collapse', 'collapse')]},
        {'selector': 'th',
         'props': [('border', '2px solid #000')]},
        {'selector': 'td',
         'props': [('border', '1px solid #000'), ('padding', '5px')]}
    ]

    summary_df = pd.DataFrame(data = summary_data, columns=["Загон", "Сумма", "Cреднаяя", "Медианная", "Макс", "Мин"])
    sum_row = pd.DataFrame({'Загон': ["Пастбище"], 'Сумма': [summary_df['Сумма'].sum()], 'Cреднаяя': [round(float(test_meet.mean()),precision)], 'Медианная': [round(float(ma.median(test_meet)),precision)], 'Макс': [summary_df['Макс'].max()], 'Мин': [summary_df['Мин'].min()]}, index=[len(summary_df.index)])
    summary_df = pd.concat([summary_df, sum_row])
    if save_excel:
        summary_df.to_excel(f"Summary_{date_chosen}_{data_collection.processing_level}.xlsx", index=None)
    styled_df = summary_df.style.set_table_styles(styles)
    styled_df.hide(axis="index")
    
    display(styled_df)

    if show_hists:
        for i, zagon in enumerate(test_index_masked_array):
            ep.hist(zagon, colors = colors[i], title=f'{header} || Загон-{i+1} {general_info}', cols=4, alpha=0.5,
            figsize = (10, 6))    
            plt.axvline(test_index_masked_array[i].mean(), color='b', linestyle='dashed', linewidth=2)
            plt.axvline(ma.median(test_index_masked_array[i]), color='r', linestyle='dashed', linewidth=2)
            has_negative_or_zero = test_index_masked_array[i] <= 0
            if not has_negative_or_zero.sum():
                plt.axvline(hmean(test_index_masked_array[i].reshape(aoi_width * aoi_height)), color='g', linestyle='dashed', linewidth=2)
                plt.axvline(gmean(test_index_masked_array[i].reshape(aoi_width * aoi_height)), color='y', linestyle='dashed', linewidth=2)
                plt.legend([f"Средняя: {test_index_masked_array[i].mean()}",f"Медианная: {ma.median(test_index_masked_array[i])}",f"Гармоническая: {hmean(test_index_masked_array[i].reshape(aoi_width * aoi_height))}",f"Геометрическая: {gmean(test_index_masked_array[i].reshape(aoi_width * aoi_height))}"], title=f'Сумма: {round(zagon.sum(),precision)}')
            else:
                plt.legend([f"Средняя: {ma.mean(test_index_masked_array[i])}",f"Медианная: {ma.median(test_index_masked_array[i])}"], title=f'Сумма: {round(zagon.sum(),precision)}')
        plt.show()
        
        
def get_all_bands(by_pasture=True):
    global ULTRA_BLUE, BLUE, GREEN, RED, RED_EDGE1, RED_EDGE2, RED_EDGE3, NIR, N_NIR, WV, SWIR_C, SWIR2, SWIR3, SAA, SZA, VAM, VZM
    
    if by_pasture:
        # Нормализированные по пастбищу
        ULTRA_BLUE = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B01"]])))

        BLUE = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B02"]])))
        GREEN = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B03"]])))
        RED = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B04"]])))

        RED_EDGE1 = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B05"]])))
        RED_EDGE2 = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B06"]])))
        RED_EDGE3 = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B07"]])))

        NIR = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B08"]])))
        N_NIR = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B8A"]])))
        WV = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B09"]])))
        if "B10" in bands_dict:
            SWIR_C = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B10"]])))
        SWIR2 = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B11"]])))
        SWIR3 = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B12"]])))
    else:
        # НЕ Нормализированные по пастбищу
        ULTRA_BLUE = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B01"]])))

        BLUE = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B02"]])))
        GREEN = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B03"]])))
        RED = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B04"]])))

        RED_EDGE1 = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B05"]])))
        RED_EDGE2 = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B06"]])))
        RED_EDGE3 = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B07"]])))

        NIR = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B08"]])))
        N_NIR = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B8A"]])))
        WV = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B09"]])))
        if "B10" in bands_dict:
            SWIR_C = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B10"]])))
        SWIR2 = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B11"]])))
        SWIR3 = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B12"]])))

    SAA = (aux_data[image_date][:, :, aux_data_dict["sunAzimuthAngles"]]).mean()
    SZA = (aux_data[image_date][:, :, aux_data_dict["sunZenithAngles"]]).mean()
    VAM = (aux_data[image_date][:, :, aux_data_dict["viewAzimuthMean"]]).mean()
    VZM = (aux_data[image_date][:, :, aux_data_dict["viewZenithMean"]]).mean()

# %% [markdown]
# # Выбор порога облачности

# %%
white_noise_threshold = 255 # Значение [0-255]  
white_noise_count = 12246 # Количество 157*78=[0-12246]

# %%
cols = 10
ncols, nrows = cols, ceil(len(results)/cols) 

fig, axis = plt.subplots(
    ncols=ncols, nrows=nrows, figsize=(60, 30), subplot_kw={"xticks": [], "yticks": [], "frame_on": False}
)

idx = 0
clear_date_dict = []
for i, (image, timestamp) in enumerate(zip(all_bands_data, unique_acquisitions)):

    data = image.astype(np.float64) / image.max()
    data = 255 * data
    image = data.astype(np.uint8)
    
#     mx1 = ma.masked_array(image[:,:,bands_dict["B02"]], mask=combined_mask.reshape(aoi_height, aoi_width))
#     mx2 = ma.masked_array(image[:,:,bands_dict["B03"]], mask=combined_mask.reshape(aoi_height, aoi_width))
#     mx3 = ma.masked_array(image[:,:,bands_dict["B04"]], mask=combined_mask.reshape(aoi_height, aoi_width))
#     comb = mx1&mx2&mx3
#     white_image = comb >= white_noise_threshold
#     if white_image.sum() <= white_noise_count:
    clear_date_dict.append((str(timestamp.date().isoformat()), i))
    ax = axis[idx // ncols][idx % ncols]
    image = np.stack([image[:,:,bands_dict["B04"]], image[:,:,bands_dict["B03"]], image[:,:,bands_dict["B02"]]])
    ax.imshow(np.transpose(image, (1, 2, 0)))
    ax.set_title(timestamp.date().isoformat(), fontsize=30)
    idx += 1
        
clear_date_dict = dict(clear_date_dict)
plt.tight_layout()

# %% [markdown]
# # Выбор доступной даты

# %%
date_chosen = "2021-08-15"
image_date = clear_date_dict[date_chosen]

get_all_bands(by_pasture=False)

precision = 4
general_info = f"|| {date_chosen} || SZA: {str(round(SZA, precision))}, VZA: {str(round(VZM, precision))} || Level: {data_collection.processing_level}"

# %% [markdown]
# # Исследование нового индекса

# %%
# input_text = "(NIR-RED) / (NIR+RED)"
input_text = "(GREEN-RED) + (NIR-SWIR3)"

test_index = eval(input_text)

# test_thresh = test_index.min() 
test_thresh = (test_index.max() + test_index.min())/2

test_filter = test_index >= test_thresh; test_mask = ~test_filter
test_meet = ma.masked_array(test_index, mask=test_mask)

# lower_bound = -1;  upper_bound = 1
lower_bound = test_meet.min(); upper_bound = test_meet.max()

show_real_pasture()
show_pasture_index(test_meet, lower_bound, upper_bound, show_hists=False, save_excel=False)
# Out:
# <style type="text/css">
# #T_18457  {
#   border: 2px solid #000;
#   border-collapse: collapse;
# }
# #T_18457 th {
#   border: 2px solid #000;
# }
# #T_18457 td {
#   border: 1px solid #000;
#   padding: 5px;
# }
# </style>
# <table id="T_18457">
#   <thead>
#     <tr>
#       <th id="T_18457_level0_col0" class="col_heading level0 col0" >Загон</th>
#       <th id="T_18457_level0_col1" class="col_heading level0 col1" >Сумма</th>
#       <th id="T_18457_level0_col2" class="col_heading level0 col2" >Cреднаяя</th>
#       <th id="T_18457_level0_col3" class="col_heading level0 col3" >Медианная</th>
#       <th id="T_18457_level0_col4" class="col_heading level0 col4" >Макс</th>
#       <th id="T_18457_level0_col5" class="col_heading level0 col5" >Мин</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_18457_row0_col0" class="data row0 col0" >№1</td>
#       <td id="T_18457_row0_col1" class="data row0 col1" >73.648903</td>
#       <td id="T_18457_row0_col2" class="data row0 col2" >0.196400</td>
#       <td id="T_18457_row0_col3" class="data row0 col3" >0.194800</td>
#       <td id="T_18457_row0_col4" class="data row0 col4" >0.379700</td>
#       <td id="T_18457_row0_col5" class="data row0 col5" >0.025900</td>
#     </tr>
#     <tr>
#       <td id="T_18457_row1_col0" class="data row1 col0" >№2</td>
#       <td id="T_18457_row1_col1" class="data row1 col1" >1.455900</td>
#       <td id="T_18457_row1_col2" class="data row1 col2" >0.060700</td>
#       <td id="T_18457_row1_col3" class="data row1 col3" >0.057900</td>
#       <td id="T_18457_row1_col4" class="data row1 col4" >0.127900</td>
#       <td id="T_18457_row1_col5" class="data row1 col5" >0.025800</td>
#     </tr>
#     <tr>
#       <td id="T_18457_row2_col0" class="data row2 col0" >№3</td>
#       <td id="T_18457_row2_col1" class="data row2 col1" >30.130501</td>
#       <td id="T_18457_row2_col2" class="data row2 col2" >0.101400</td>
#       <td id="T_18457_row2_col3" class="data row2 col3" >0.081600</td>
#       <td id="T_18457_row2_col4" class="data row2 col4" >0.393300</td>
#       <td id="T_18457_row2_col5" class="data row2 col5" >0.026000</td>
#     </tr>
#     <tr>
#       <td id="T_18457_row3_col0" class="data row3 col0" >№4</td>
#       <td id="T_18457_row3_col1" class="data row3 col1" >133.573593</td>
#       <td id="T_18457_row3_col2" class="data row3 col2" >0.214100</td>
#       <td id="T_18457_row3_col3" class="data row3 col3" >0.236500</td>
#       <td id="T_18457_row3_col4" class="data row3 col4" >0.411600</td>
#       <td id="T_18457_row3_col5" class="data row3 col5" >0.026500</td>
#     </tr>
#     <tr>
#       <td id="T_18457_row4_col0" class="data row4 col0" >№5</td>
#       <td id="T_18457_row4_col1" class="data row4 col1" >143.694901</td>
#       <td id="T_18457_row4_col2" class="data row4 col2" >0.185400</td>
#       <td id="T_18457_row4_col3" class="data row4 col3" >0.170100</td>
#       <td id="T_18457_row4_col4" class="data row4 col4" >0.416800</td>
#       <td id="T_18457_row4_col5" class="data row4 col5" >0.025900</td>
#     </tr>
#     <tr>
#       <td id="T_18457_row5_col0" class="data row5 col0" >№6</td>
#       <td id="T_18457_row5_col1" class="data row5 col1" >80.671898</td>
#       <td id="T_18457_row5_col2" class="data row5 col2" >0.130700</td>
#       <td id="T_18457_row5_col3" class="data row5 col3" >0.126000</td>
#       <td id="T_18457_row5_col4" class="data row5 col4" >0.315200</td>
#       <td id="T_18457_row5_col5" class="data row5 col5" >0.026200</td>
#     </tr>
#     <tr>
#       <td id="T_18457_row6_col0" class="data row6 col0" >№7</td>
#       <td id="T_18457_row6_col1" class="data row6 col1" >73.726601</td>
#       <td id="T_18457_row6_col2" class="data row6 col2" >0.107500</td>
#       <td id="T_18457_row6_col3" class="data row6 col3" >0.094500</td>
#       <td id="T_18457_row6_col4" class="data row6 col4" >0.305300</td>
#       <td id="T_18457_row6_col5" class="data row6 col5" >0.025900</td>
#     </tr>
#     <tr>
#       <td id="T_18457_row7_col0" class="data row7 col0" >Пастбище</td>
#       <td id="T_18457_row7_col1" class="data row7 col1" >536.902283</td>
#       <td id="T_18457_row7_col2" class="data row7 col2" >0.158300</td>
#       <td id="T_18457_row7_col3" class="data row7 col3" >0.137000</td>
#       <td id="T_18457_row7_col4" class="data row7 col4" >0.416800</td>
#       <td id="T_18457_row7_col5" class="data row7 col5" >0.025800</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Разбивка на кластеры

# %%
# n_clusters = 3
# for cluster_mask in Kcluster(test_meet, n_clusters):
#     cluster = ma.masked_array(test_meet, mask=cluster_mask.reshape(aoi_height, aoi_width))
#     fig, ax = plt.subplots(figsize=(12, 12))
#     for zagon in range(len(pasture_df)-1):

#         ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])

#     ep.plot_bands(cluster_mask, title=f"Кластер значении [{round(float(cluster.min()),precision)} - {round(float(cluster.max()),precision)}] канала {input_text} {general_info}", ax=ax, figsize=(10, 14))
# plt.show()

# %% [markdown]
# # Вывод всех каналов по отдельности

# %%
fig, ax = plt.subplots(figsize=(12, 5))
for zagon in range(len(pasture_df)-1):

    ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])

plt.imshow(ULTRA_BLUE, cmap="Blues", vmin=ULTRA_BLUE.min(), vmax=ULTRA_BLUE.max())
plt.title(f"B01 Coastal Aerosol {general_info}")
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
for zagon in range(len(pasture_df)-1):

    ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])

plt.imshow(BLUE, cmap="Blues", vmin=BLUE.min(), vmax=BLUE.max())
plt.title(f"B02 Blue {general_info}")
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
for zagon in range(len(pasture_df)-1):

    ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])

plt.imshow(GREEN, cmap="Greens", vmin=GREEN.min(), vmax=GREEN.max())
plt.title(f"B03 Green {general_info}")
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
for zagon in range(len(pasture_df)-1):

    ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])

plt.imshow(RED, cmap="Reds", vmin=RED.min(), vmax=RED.max())
plt.title(f"B04 Red {general_info}")
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
for zagon in range(len(pasture_df)-1):

    ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])

plt.imshow(RED_EDGE1, cmap="viridis", vmin=RED_EDGE1.min(), vmax=RED_EDGE1.max())
plt.title(f"B05 Red edge 1 {general_info}")
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
for zagon in range(len(pasture_df)-1):

    ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])

plt.imshow(RED_EDGE2, cmap="viridis", vmin=RED_EDGE2.min(), vmax=RED_EDGE2.max())
plt.title(f"B06 Red edge 2 {general_info}")
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
for zagon in range(len(pasture_df)-1):

    ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])

plt.imshow(RED_EDGE3, cmap="viridis", vmin=RED_EDGE3.min(), vmax=RED_EDGE3.max())
plt.title(f"B07 Red edge 3 {general_info}")
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
for zagon in range(len(pasture_df)-1):

    ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])

plt.imshow(NIR, cmap="viridis", vmin=NIR.min(), vmax=NIR.max())
plt.title(f"B08 NIR {general_info}")
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
for zagon in range(len(pasture_df)-1):

    ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])

plt.imshow(N_NIR, cmap="viridis", vmin=N_NIR.min(), vmax=N_NIR.max())
plt.title(f"B8A Narrow NIR {general_info}")
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
for zagon in range(len(pasture_df)-1):

    ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])

plt.imshow(WV, cmap="viridis", vmin=WV.min(), vmax=WV.max())
plt.title(f"B09 Water vapor {general_info}")
plt.colorbar()
plt.show()

# %%
if "B10" in bands_dict:
    fig, ax = plt.subplots(figsize=(12, 5))
    for zagon in range(len(pasture_df)-1):

        ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])

    plt.imshow(SWIR_C, cmap="viridis", vmin=SWIR_C.min(), vmax=SWIR_C.max())
    plt.title(f"B10 SWIR C {general_info}")
    plt.colorbar()
    plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
for zagon in range(len(pasture_df)-1):

    ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])

plt.imshow(SWIR2, cmap="viridis", vmin=SWIR2.min(), vmax=SWIR2.max())
plt.title(f"B11 SWIR 2 {general_info}")
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 5))
for zagon in range(len(pasture_df)-1):

    ax.plot(pasture_edges[zagon].exterior.xy[1], pasture_edges[zagon].exterior.xy[0])

plt.imshow(SWIR3, cmap="viridis", vmin=SWIR3.min(), vmax=SWIR3.max())
plt.title(f"B11 SWIR 3 {general_info}")
plt.colorbar()
plt.show()

# %% [markdown]
# # Анализ погодных параметров и каналов

# %% [markdown]
# ## Координаты пастбища

# %%
longitude = pasture_bbox.geometry.centroid.coords.xy[0][0]
latitude = pasture_bbox.geometry.centroid.coords.xy[1][0]

# %%
forecast_parameters = [
"temperature_2m_max",
"temperature_2m_min",
"apparent_temperature_max",
"apparent_temperature_min",
"precipitation_sum",
"rain_sum",
"showers_sum",
"snowfall_sum",
"precipitation_hours",
"precipitation_probability_max",
"precipitation_probability_min",
"precipitation_probability_mean",
"weathercode",
"sunrise",
"sunset",
"windspeed_10m_max",
"windgusts_10m_max",
"winddirection_10m_dominant",
"shortwave_radiation_sum",
"et0_fao_evapotranspiration",
"uv_index_max",
"uv_index_clear_sky_max",]

history_parameters = [
"temperature_2m_max",
"temperature_2m_min",
"apparent_temperature_max",
"apparent_temperature_min",
"precipitation_sum",
"rain_sum",
"snowfall_sum",
"precipitation_hours",
"weathercode",
"sunrise",
"sunset",
"windspeed_10m_max",
"windgusts_10m_max",
"winddirection_10m_dominant",
"shortwave_radiation_sum",
"et0_fao_evapotranspiration",]


last_main_description = ""

def get_weather_mapping():
    global last_main_description
    
    url = "https://www.nodc.noaa.gov/archive/arc0021/0002199/1.1/data/0-data/HTML/WMO-CODE/WMO4677.HTM"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    weather_mapping = {}
    
    for i_table, table in enumerate(soup.select('table[BORDER]')):
        for i_row, row in enumerate(table.find_all('tr')[1:]):
            code_and_description = row.find_all('td')[:2]
            code = int(code_and_description[0].text.strip())
            description = code_and_description[1].text.strip()
            if not description.startswith("-"):
                last_main_description = description
            else:
                description = last_main_description
            weather_mapping[code] = description
            
            
    return weather_mapping

def weather_code_to_string(wmo_code):
    return weather_mapping.get(wmo_code, "Unknown Weather Code")

# Generate the weather mapping
weather_mapping = get_weather_mapping()


def apply_params_to_URL(URL, parameters):
    URL += "&daily="
    for i, parameter in enumerate(parameters):
        if i < len(parameters) - 1:
            URL += parameter + ","
        else:
            URL += parameter
    URL += "&timezone=auto"
    
#     print("URL updated: ", URL)
    return URL

def make_API_request(URL):
    try:
        # Convert from bytes to text
        resp_text = urllib.request.urlopen(URL).read().decode('UTF-8')
        # Use loads to decode from text
        json_obj = json.loads(resp_text)
#         print("Successfull API request!")
        return json_obj
    except urllib.error.HTTPError  as e:
        ErrorInfo= e.read().decode()
        print('Error code: ', e.code, ErrorInfo)
        sys.exit()
    except  urllib.error.URLError as e:
        ErrorInfo= e.read().decode()
        print('Error code: ', e.code,ErrorInfo)
        sys.exit()

# %% [markdown]
# # История погоды по заданному диапазону

# %%
dates_to_analyze = [
    '2017-06-17',
    '2017-06-27',
    '2017-07-17',
    '2017-07-27',
    '2017-08-01',
    '2017-08-11',
    '2017-08-16',
    '2017-08-26',
    '2017-08-29',
    '2017-08-31',
    '2018-05-23',
    '2018-05-28',
    '2018-06-07',
    '2018-07-02',
    '2018-08-06',
    '2018-08-14',
    '2019-05-01',
    '2019-05-03',
    '2019-05-08',
    '2019-05-28',
    '2019-06-12',
    '2019-07-07',
    '2019-07-12',
    '2019-07-27',
    '2019-08-11',
    '2019-08-14',
    '2019-08-24',
    '2020-05-07',
    '2020-05-12',
    '2020-05-27',
    '2020-06-06',
    '2020-06-16',
    '2020-07-06',
    '2020-07-16',
    '2020-07-29',
    '2020-08-03',
    '2020-08-05',
    '2020-08-28',
    '2020-08-30',
    '2021-05-02',
    '2021-05-07',
    '2021-05-15',
    '2021-05-17',
    '2021-05-22',
    '2021-06-06',
    '2021-06-16',
    '2021-06-26',
    '2021-07-01',
    '2021-07-21',
    '2021-07-26',
    '2021-07-31',
    '2021-08-13',
    '2021-08-15',
    '2021-08-18',
    '2021-08-20',
    '2021-08-23',
    '2021-08-25',
    '2021-08-30',
    '2022-05-07',
    '2022-05-12',
    '2022-06-01',
    '2022-07-01',
    '2022-07-26',
    '2022-08-03',
    '2022-08-05',
    '2022-08-10',
    '2022-08-13',
    '2022-08-25',
    '2022-08-28',
    '2022-08-30',
    '2023-05-02',
    '2023-05-05',
    '2023-05-07',
    '2023-05-12',
    '2023-05-17',
    '2023-05-22',
    '2023-06-06',
    '2023-06-11',
    '2023-07-01',
    '2023-07-11',
    '2023-07-26',
    '2023-08-18',
    '2023-08-20',
    '2023-08-23',
]

# %%
start_date = "2022-05-01" 
end_date = "2022-08-31"

start_date = dates_to_analyze[0]
end_date = dates_to_analyze[-1]

# %%
Hist_URL = f"https://archive-api.open-meteo.com/v1/archive?latitude={latitude}&longitude={longitude}&start_date={start_date}&end_date={end_date}"

# %%
Hist_URL = apply_params_to_URL(Hist_URL, history_parameters)

# %%
history_json_obj = make_API_request(Hist_URL)

# %%
history_df = pd.DataFrame(history_json_obj["daily"])

# %%
history_df

# %%
history_fraction_df = history_df[history_df['time'].isin(dates_to_analyze)]
history_fraction_df.reset_index(drop=True, inplace=True)
history_fraction_df.drop(columns=["weathercode", "sunrise", "sunset"], inplace=True)

# %%
history_fraction_df

# %% [markdown]
# # Дополнительная вспомогательная функция для сбора данных ДЗЗ

# %%
def get_date_data(date_chosen, collection, by_pasture=True, median=False):
    global bands_dict

    if collection == "L1C":
        data_collection = DataCollection.SENTINEL2_L1C
    elif collection == "L2A":
        data_collection = DataCollection.SENTINEL2_L2A

    bands_dict = dict([(band.name, i) for i, band in enumerate(data_collection.bands)])
    aux_data_dict = dict([(band, i) for i, band in enumerate(["sunZenithAngles","sunAzimuthAngles","viewZenithMean","viewAzimuthMean"])])

    evalscript_all_bands = """
        //VERSION=3
        function setup() {{
            return {{
                input: [{{
                    bands: [{BANDS}],
                    units: "DN"
                }}],
                output: {{
                    bands: {COUNT},
                    sampleType: "FLOAT32"
                }}
            }};
        }}

        function evaluatePixel(sample) {{
            return [{SAMPLE}];
        }}
    """
    template1 = ""; template2 = ""
    for band in bands_dict.keys():
        template1 += f'"{band}", ';
        template2 += f'sample.{band}, ';
    settings = {"BANDS": template1, "SAMPLE": template2, "COUNT": str(len(bands_dict))}
    evalscript_all_bands = evalscript_all_bands.format(**settings)


    evalscript_aux_data = """
        //VERSION=3

        function setup() {{
            return {{
                input: [{{
                    bands: [{BANDS}],
                    units: "DEGREES"
                }}],
                output: {{
                    bands: {COUNT},
                    sampleType: "FLOAT32"
                }}
            }};
        }}

        function evaluatePixel(sample) {{
            return [{SAMPLE}];
        }}
    """
    template1 = ""; template2 = ""
    for band in aux_data_dict.keys():
        template1 += f'"{band}", ';
        template2 += f'sample.{band}, ';
    settings = {"BANDS": template1, "SAMPLE": template2, "COUNT": str(len(aux_data_dict))}
    evalscript_aux_data = evalscript_aux_data.format(**settings)


    time_interval = date_chosen, date_chosen

    search_iterator = catalog.search(
        data_collection,
        bbox=pasture_bbox,
        time=time_interval,
        filter="eo:cloud_cover <= 100",
        fields={"include": ["id", "properties.datetime", "properties.eo:cloud_cover"], "exclude": []},
    )

    results = list(search_iterator)

    time_difference = datetime.timedelta(hours=1)
    all_timestamps = search_iterator.get_timestamps()
    unique_acquisitions = filter_times(all_timestamps, time_difference)


    all_bands_process_requests = []

    for timestamp in unique_acquisitions:
        request = SentinelHubRequest(
            evalscript=evalscript_all_bands,
            input_data=[
                SentinelHubRequest.input_data(
                    data_collection=data_collection,
                    time_interval=(timestamp - time_difference, timestamp + time_difference),
                )
            ],
            responses=[SentinelHubRequest.output_response("default", MimeType.TIFF)],
            bbox=pasture_bbox,
            size=pasture_size,
            config=config,
        )
        all_bands_process_requests.append(request)

    aux_data_process_requests = []

    for timestamp in unique_acquisitions:
        request = SentinelHubRequest(
            evalscript=evalscript_aux_data,
            input_data=[
                SentinelHubRequest.input_data(
                    data_collection=data_collection,
                    time_interval=(timestamp - time_difference, timestamp + time_difference),
                )
            ],
            responses=[SentinelHubRequest.output_response("default", MimeType.TIFF)],
            bbox=pasture_bbox,
            size=pasture_size,
            config=config,
        )
        aux_data_process_requests.append(request)

    client = SentinelHubDownloadClient(config=config)
    all_bands_download_requests = [request.download_list[0] for request in all_bands_process_requests]
    all_bands_data = client.download(all_bands_download_requests)

    client = SentinelHubDownloadClient(config=config)
    aux_data_download_requests = [request.download_list[0] for request in aux_data_process_requests]
    aux_data = client.download(aux_data_download_requests)

    white_noise_threshold = 255 # Значение [0-255]
    white_noise_count = 12246 # Количество 157*78=[0-12246]

    clear_date_dict = []
    for i, (image, timestamp) in enumerate(zip(all_bands_data, unique_acquisitions)):

        data = image.astype(np.float64) / image.max()
        data = 255 * data
        image = data.astype(np.uint8)

        mx1 = ma.masked_array(image[:,:,bands_dict["B02"]], mask=combined_mask.reshape(aoi_height, aoi_width))
        mx2 = ma.masked_array(image[:,:,bands_dict["B03"]], mask=combined_mask.reshape(aoi_height, aoi_width))
        mx3 = ma.masked_array(image[:,:,bands_dict["B04"]], mask=combined_mask.reshape(aoi_height, aoi_width))
        comb = mx1&mx2&mx3
        white_image = comb >= white_noise_threshold
        if white_image.sum() <= white_noise_count:
            clear_date_dict.append((str(timestamp.date().isoformat()), i))

    clear_date_dict = dict(clear_date_dict)
    image_date = clear_date_dict[date_chosen]

    SAA = (aux_data[image_date][:, :, aux_data_dict["sunAzimuthAngles"]]).mean()
    SZA = (aux_data[image_date][:, :, aux_data_dict["sunZenithAngles"]]).mean()
    VAM = (aux_data[image_date][:, :, aux_data_dict["viewAzimuthMean"]]).mean()
    VZM = (aux_data[image_date][:, :, aux_data_dict["viewZenithMean"]]).mean()

    if by_pasture:
        # Нормализированные по пастбищу
        ULTRA_BLUE = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B01"]])))

        BLUE = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B02"]])))
        GREEN = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B03"]])))
        RED = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B04"]])))

        RED_EDGE1 = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B05"]])))
        RED_EDGE2 = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B06"]])))
        RED_EDGE3 = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B07"]])))

        NIR = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B08"]])))
        N_NIR = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B8A"]])))
        WV = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B09"]])))
        if "B10" in bands_dict:
            SWIR_C = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B10"]])))
        SWIR2 = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B11"]])))
        SWIR3 = normalize(brighten(get_only_pasture(all_bands_data[image_date][:, :, bands_dict["B12"]])))

    else:
        # НЕ Нормализированные по пастбищу
        ULTRA_BLUE = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B01"]])))

        BLUE = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B02"]])))
        GREEN = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B03"]])))
        RED = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B04"]])))

        RED_EDGE1 = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B05"]])))
        RED_EDGE2 = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B06"]])))
        RED_EDGE3 = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B07"]])))

        NIR = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B08"]])))
        N_NIR = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B8A"]])))
        WV = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B09"]])))
        if "B10" in bands_dict:
            SWIR_C = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B10"]])))
        SWIR2 = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B11"]])))
        SWIR3 = get_only_pasture(normalize(brighten(all_bands_data[image_date][:, :, bands_dict["B12"]])))

    ndvi = (NIR - RED) / (NIR + RED)
    savi = (NIR - RED) / (NIR + RED + 0.5) * (1 + 0.5)
    revi = (NIR / RED_EDGE1) - 1
    evi = 2.5 * (NIR - RED) / (NIR + 6 * RED - 7.5 * BLUE + 1)
    tvi = np.sqrt((NIR - RED) / (NIR + RED) + 0.0)
    gndvi = (NIR - GREEN) / (NIR + GREEN)
    ndii = (NIR - SWIR3) / (NIR + SWIR3)
    cvi = (NIR / RED) - 1
    gci = (NIR / GREEN) - 1
    pri = (RED_EDGE1 - RED) / (RED_EDGE1 + RED)
    ndre = (NIR - RED_EDGE1) / (NIR + RED_EDGE1)
    osavi = (NIR - RED) / (NIR + RED + 0.16)
    arvi = (NIR - (2 * RED) + BLUE) / (NIR + (2 * RED) + BLUE)
    vari = (RED+BLUE-GREEN)
    my_index = (GREEN-RED)+(NIR-SWIR3)



    print(f"Успешно получены каналы для даты: {date_chosen}")
    if median:
        if "B10" in bands_dict:
            return ["time"] + list(bands_dict.keys()) + ["ndvi", "savi", "revi", "evi", "tvi", "gndvi", "ndii", "cvi", "gci", "pri", "ndre", "osavi", "arvi", "vari", "my_index",] + list(aux_data_dict.keys()), [date_chosen, ma.median(ULTRA_BLUE), ma.median(BLUE), ma.median(GREEN), ma.median(RED), ma.median(RED_EDGE1), ma.median(RED_EDGE2), ma.median(RED_EDGE3), ma.median(NIR), ma.median(N_NIR), ma.median(WV), ma.median(SWIR_C), ma.median(SWIR2), ma.median(SWIR3), ma.median(ndvi), ma.median(savi), ma.median(revi), ma.median(evi), ma.median(tvi), ma.median(gndvi), ma.median(ndii), ma.median(cvi), ma.median(gci), ma.median(pri), ma.median(ndre), ma.median(osavi), ma.median(arvi), ma.median(vari), ma.median(my_index), SZA, SAA, VZM, VAM]
        else:
            return ["time"] + list(bands_dict.keys()) + ["ndvi", "savi", "revi", "evi", "tvi", "gndvi", "ndii", "cvi", "gci", "pri", "ndre", "osavi", "arvi", "vari", "my_index",] + list(aux_data_dict.keys()), [date_chosen, ma.median(ULTRA_BLUE), ma.median(BLUE), ma.median(GREEN), ma.median(RED), ma.median(RED_EDGE1), ma.median(RED_EDGE2), ma.median(RED_EDGE3), ma.median(NIR), ma.median(N_NIR), ma.median(WV), ma.median(SWIR2), ma.median(SWIR3), ma.median(ndvi), ma.median(savi), ma.median(revi), ma.median(evi), ma.median(tvi), ma.median(gndvi), ma.median(ndii), ma.median(cvi), ma.median(gci), ma.median(pri), ma.median(ndre), ma.median(osavi), ma.median(arvi), ma.median(vari), ma.median(my_index), SZA, SAA, VZM, VAM]
    else:
        if "B10" in bands_dict:
            return ["time"] + list(bands_dict.keys()) + ["ndvi", "savi", "revi", "evi", "tvi", "gndvi", "ndii", "cvi", "gci", "pri", "ndre", "osavi", "arvi", "vari", "my_index",] + list(aux_data_dict.keys()), [date_chosen, ma.mean(ULTRA_BLUE), ma.mean(BLUE), ma.mean(GREEN), ma.mean(RED), ma.mean(RED_EDGE1), ma.mean(RED_EDGE2), ma.mean(RED_EDGE3), ma.mean(NIR), ma.mean(N_NIR), ma.mean(WV), ma.mean(SWIR_C), ma.mean(SWIR2), ma.mean(SWIR3), ma.mean(ndvi), ma.mean(savi), ma.mean(revi), ma.mean(evi), ma.mean(tvi), ma.mean(gndvi), ma.mean(ndii), ma.mean(cvi), ma.mean(gci), ma.mean(pri), ma.mean(ndre), ma.mean(osavi), ma.mean(arvi), ma.mean(vari), ma.mean(my_index), SZA, SAA, VZM, VAM]
        else:
            return ["time"] + list(bands_dict.keys()) + ["ndvi", "savi", "revi", "evi", "tvi", "gndvi", "ndii", "cvi", "gci", "pri", "ndre", "osavi", "arvi", "vari", "my_index",] + list(aux_data_dict.keys()), [date_chosen, ma.mean(ULTRA_BLUE), ma.mean(BLUE), ma.mean(GREEN), ma.mean(RED), ma.mean(RED_EDGE1), ma.mean(RED_EDGE2), ma.mean(RED_EDGE3), ma.mean(NIR), ma.mean(N_NIR), ma.mean(WV), ma.mean(SWIR2), ma.mean(SWIR3), ma.mean(ndvi), ma.mean(savi), ma.mean(revi), ma.mean(evi), ma.mean(tvi), ma.mean(gndvi), ma.mean(ndii), ma.mean(cvi), ma.mean(gci), ma.mean(pri), ma.mean(ndre), ma.mean(osavi), ma.mean(arvi), ma.mean(vari), ma.mean(my_index), SZA, SAA, VZM, VAM]

# %% [markdown]
# # Получение данных ДЗЗ по доступным датам

# %%
sample_form = []
for date in dates_to_analyze:
    data_lables, data_list = get_date_data(date, "L2A", by_pasture=False, median=False)
    sample_form.append(data_list)

# %%
indices_df = pd.DataFrame(sample_form, columns=data_lables)
# indices_df = indices_df[indices_df != "--"].dropna()
indices_df

# %% [markdown]
# # Подготовка таблиц

# %%
joined_df = pd.merge(indices_df, history_fraction_df, on='time', how='outer')
joined_df

# %%
correlation_matrix = joined_df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(48, 40))

cmap = sns.diverging_palette(120, 120, as_cmap=True)

# Plot the correlation matrix using a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap=cmap, fmt=".2f", linewidths=.5)

# Adjust the x-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Draw a separation line after the 5th column (index 4)
plt.axvline(x=12, color='black', linestyle='-', linewidth=4)
plt.axvline(x=27, color='black', linestyle='-', linewidth=4)
plt.axvline(x=31, color='black', linestyle='-', linewidth=4)

plt.axhline(y=12, color='black', linestyle='-', linewidth=4)
plt.axhline(y=27, color='black', linestyle='-', linewidth=4)
plt.axhline(y=31, color='black', linestyle='-', linewidth=4)

x = np.arange(correlation_matrix.shape[0])
plt.plot(x, x, color='blue', linestyle='-', linewidth=4)

# Adjust the x-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Show the plot
plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# # Выбор диапазона дат выпаса

# %%
start_date = "2023-05-01"
end_date = "2023-08-31"

start_date = datetime.datetime.strptime(start_date, "%Y-%m-%d")
end_date = datetime.datetime.strptime(end_date, "%Y-%m-%d")
grazing_duration = end_date - start_date

# %% [markdown]
# # Модуляция роста растении

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters for the growth model
max_growth = 1.0  # Maximum growth (1.0 means reaching 1 but not exceeding it)
scaling_factor = 0.03  # Adjust the scaling factor to control the rate of growth

# Generate data for plant growth
x = np.linspace(0, grazing_duration.days, 1000)  # Adjust the range and number of points as needed

# Use the logarithmic function with scaling factor to model plant growth
y = max_growth * (1 - np.exp(-scaling_factor * x))

# Create the plot
plt.figure(figsize=(10, 5))
plt.plot(x, y, label="Plant Growth")
plt.xlabel("Time")
plt.ylabel("Growth")
plt.title("Plant Growth Over Time with Increasing Logarithmic Slope (Approaching 1)")

plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# # Общий рост по сезону

# %%
season_start_date = "2023-03-01"
season_end_date = "2023-09-30"
season_start_date = datetime.datetime.strptime(season_start_date, "%Y-%m-%d")
season_end_date = datetime.datetime.strptime(season_end_date, "%Y-%m-%d")
season_duration = season_end_date - season_start_date

first_peak = "2023-04-01"; max1_y = 0.5
second_peak = "2023-08-20"; max2_y = 0.3

first_peak = datetime.datetime.strptime(first_peak, "%Y-%m-%d")
second_peak = datetime.datetime.strptime(second_peak, "%Y-%m-%d")


# Define the two maximum points
max1_x = (first_peak - season_start_date).days  # x value of the first maximum point
max2_x = (second_peak - season_start_date).days  # x value of the second maximum point


# Generate x values (months)
x = np.linspace(0, season_duration.days, season_duration.days)  # Adjust the range as needed

sigma = 50  # Increase this value to make the curve less steep

# Calculate the y values based on the Gaussian distribution for the two maxima
y = max1_y * np.exp(-((x - max1_x) / sigma) ** 2) + max2_y * np.exp(-((x - max2_x) / sigma) ** 2)

# Initialize an empty list to store month labels
custom_x_ticks = []

# Generate month labels for each month in the season duration
current_date = season_start_date
while current_date <= season_end_date:
    custom_x_ticks.append(current_date.strftime("%b"))
    current_date = current_date + datetime.timedelta(days=30)  # Approximate number of days in a month

# Ensure the last label is "Sep" to match the season end date

# Remove duplicate month labels if any
custom_x_ticks = list(set(custom_x_ticks))

# Sort the month labels in chronological order
custom_x_ticks.sort(key=lambda x: datetime.datetime.strptime(x, "%b").month)
# Calculate the positions of the custom x ticks
# In this case, I'm spreading them evenly across the x-axis
custom_x_tick_positions = np.linspace(0, season_duration.days, len(custom_x_ticks))

# Create the plot
plt.figure(figsize=(10, 5))
plt.plot(x, y, label="Коэффициент роста растений", color="green")
plt.xlabel("Месяц")
plt.ylabel("Коэффициент")
plt.title("Сезонный коэффициент роста растений")

max_y_tick = 1.0  # Adjust this value as needed
plt.yticks(np.arange(0, max_y_tick + 0.1, 0.1))  # Set y ticks from 0 to max_y_tick

# Set the custom x tick positions and labels
plt.xticks(custom_x_tick_positions, custom_x_ticks)

plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# # Фаза роста растения(ий)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data
x = np.linspace(0, grazing_duration.days, 1000)  # Adjust the range and number of points as needed

# Define parameters for the sigmoid function
growth_rate = 0.2
midpoint = 80
plateau_value = 1

# Model grass growth with a sigmoid function
y = plateau_value / (1 + np.exp(-growth_rate * (x - midpoint)))

# Create the plot
plt.figure(figsize=(10, 5))
plt.plot(x, y, label="Grass Growth")
plt.xlabel("Days from May to August")
plt.ylabel("Growth")
plt.title("Grass Growth Over Time with S-Shaped Decay")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# # Модуляция поедания растении

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define a constant value
constant_value = 0.5

# Create an array with the constant value
x = np.linspace(0, grazing_duration.days, 1000)  # Adjust the range and number of points as needed
constant_data = np.full_like(x, constant_value)

# Create the plot
plt.figure(figsize=(10, 5))
plt.plot(x, constant_data, label="Constant Value")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Plot of a Constant Value")

plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# # Модуляция отмирания растении

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data for plant growth
x = np.linspace(0, grazing_duration.days, 1000)  # Adjust the range and number of points as needed

# Use a linear function to model plant growth
y = x / grazing_duration.days  # Linear growth from 0 to 1

# Create the plot
plt.figure(figsize=(10, 5))
plt.plot(x, y, label="Plant Growth")
plt.xlabel("Time")
plt.ylabel("Growth")
plt.title("Plant Growth Over Time with Linear Growth from 0 to 1")

plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# # Симуляция параметров пастбища и поведения скота

# %% [markdown]
# ## Вспомогательные функции

# %%
breed_factors = {
    "Angus": 0.025,
    "Hereford": 0.026,
    "Limousin": 0.028,
    "Charolais": 0.029,
}

def estimated_daily_weight_gain(initial_weight, age_in_months, breed_type):
    A = 0.025
    B = int(np.interp(6, [12, 24], [20, 80]))
    C = breed_factors.get(breed_type, 0.027)
    DWG = A * (initial_weight - B) * C
    return round(DWG, 4)

def dry_matter_intake(initial_weight, breed_type):
    D = breed_factors.get(breed_type, 0.027)
    DMI = D * initial_weight
    return round(DMI, 4)

# %%
class Cattle():
    cattle_count = 0
    cattle_stack = []
    
    def __init__(self, sex, weight, stage=None, breed="Angus", production="beef", age=12, forage_to_gain=0.25):
        self.breed = breed           # Порода
        self.sex = sex               # Пол: Корова/Бык
        self.production = production # Направление: Молочное/Мясное
        self.age = age               # Возраст
        self.stage = stage           # Стадия/период
        self.weight = weight         # Начальный вес
        
        self.current_paddock = None
        self.day_entered = None
        
        self.gps_coordinate = None
        
        self.already_consumed_forage = 0
        self.forage_needed = None
        self.forage_to_gain = forage_to_gain # 1 кг сухой массы = 0.25 кг прирост в массе
        
        self.forage_needed = dry_matter_intake(self.weight, self.breed)
        
        Cattle.cattle_count += 1
        Cattle.cattle_stack.append(self)
        self.index = Cattle.cattle_count
    
    def update_age(self, grazing_day):
        if grazing_day % 30 == 0:
            self.age += 1
    
    def update_weight(self):
        weight_gain = estimated_daily_weight_gain(self.weight, self.age, self.breed)
        self.weight += weight_gain
        
    def update_forage_consumption(self):
        self.forage_needed = dry_matter_intake(self.weight, self.breed)
        
            
            
    def __str__(self):
        return f'Cattle №{self.index}. Already consumed: {self.already_consumed_forage} kg. In the paddock №{self.current_paddock} right now.'
    def __repr__(self):
        return f'Cattle №{self.index}. Already consumed: {self.already_consumed_forage} kg. In the paddock №{self.current_paddock} right now.'
    
    def enter_into_paddock(new_paddock_number):
        self.current_paddock = new_paddock_number
        self.day_entered = datetime.datetime.today()
        
    
    def get_gps_coordinate_request(self):
        # Making a request to intermediate module of the system
        # Obtaining GPS coordinates of an interested cattle 
        self.gps_coordinate = (0, 0)
        return self.gps_coordinate
    
    def get_cattle_current_gps_coordinates(self):
        gps_coordinate = self.get_gps_coordinate_request()
        curr_coord_y, curr_coord_x = gps_coordinate # (Latitude, Longitude) = (54.216885, 69.517046)
        x = int(np.interp(curr_coord_x, [x_min, x_max], [0, aoi_width])) # 157
        y = int(np.interp(curr_coord_y, [y_min, y_max], [aoi_height, 0])) # 78

        print(f"Координаты: {curr_coord_y}, {curr_coord_x} || Пиксельный эквивалент: {y}, {x}")
        for i, paddock in enumerate(masks, start=1):
            if not paddock.reshape(aoi_height, aoi_width)[y, x]:
                self.current_paddock = i
            else:
                self.current_paddock = None
    
    
class Plant():
    
    def __init__(self, name, growth_rate, death_rate, 
                 temperature_range, moisture_range, radiation_range,
                 season_start_date = "2023-03-01",
                 season_end_date = "2023-09-30",
                 first_peak = "2023-04-01", max1_y = 0.9,
                 second_peak = "2023-08-20", max2_y = 0.6,
                 sigma = 50,
                 plant_density = 150, # кг/м3
                ):
        self.name = name
        
        self.growth_rate = growth_rate # мм/день  
        self.death_rate = death_rate   # мм/день
        
        self.temperature_range = temperature_range
        self.moisture_range = moisture_range
        self.radiation_range = radiation_range
        self.score_range = input_values = [0, 1, 0]
        
        self.max1_y = max1_y
        self.max2_y = max2_y
        self.sigma = sigma
        self.plant_density = plant_density
                        
        self.season_start_date = datetime.datetime.strptime(season_start_date, "%Y-%m-%d")
        self.season_end_date = datetime.datetime.strptime(season_end_date, "%Y-%m-%d")
        self.season_duration = self.season_end_date - self.season_start_date

        self.first_peak = datetime.datetime.strptime(first_peak, "%Y-%m-%d")
        self.second_peak = datetime.datetime.strptime(second_peak, "%Y-%m-%d")
        
        
    def get_condition_score(self, grazing_day):
#         grazing_day = datetime.datetime.strptime(grazing_day, "%Y-%m-%d")
        start_date = grazing_day + datetime.timedelta(-15)
        end_date = grazing_day + datetime.timedelta(+15)
        
#         Hist_URL = f"https://archive-api.open-meteo.com/v1/archive?latitude={latitude}&longitude={longitude}&start_date={start_date.date()}&end_date={end_date.date()}"
#         Hist_URL = apply_params_to_URL(Hist_URL, history_parameters)
#         history_json_obj = make_API_request(Hist_URL)
#         history_df = pd.DataFrame(history_json_obj["daily"])
#         history_df.drop(columns=["weathercode", "sunrise", "sunset"], inplace=True)
        
        filtered_df = Plant.history_df[(Plant.history_df['time'] >= str(start_date)) & (Plant.history_df['time'] <= str(end_date))]

        temperature = np.array((filtered_df['temperature_2m_max'] + filtered_df['temperature_2m_min']) / 2)
        precipitation = np.array(filtered_df['precipitation_sum'])
        radiation = np.array(filtered_df['shortwave_radiation_sum'])
        
        temperature_score = np.interp(temperature, self.temperature_range, self.score_range, left=self.score_range[0], right=self.score_range[-1]).mean()
        precipitation_score = np.interp(precipitation, self.moisture_range, self.score_range, left=self.score_range[0], right=self.score_range[-1]).mean()
        radiation_score = np.interp(radiation, self.radiation_range, self.score_range, left=self.score_range[0], right=self.score_range[-1]).mean()
                
        return np.array([temperature_score, precipitation_score, radiation_score]).mean()
        
        
    def get_seasonal_score(self, grazing_day):
#         grazing_day = datetime.datetime.strptime(grazing_day, "%Y-%m-%d")
        days_passed = (grazing_day - self.season_start_date).days
        
        self.max1_x = (self.first_peak - self.season_start_date).days  # x value of the first maximum point
        self.max2_x = (self.second_peak - self.season_start_date).days  # x value of the second maximum point

        self.x = np.linspace(0, self.season_duration.days, self.season_duration.days)  # Adjust the range as needed

        self.sigma = 50  # Increase this value to make the curve less steep

        self.y = self.max1_y * np.exp(-((self.x - self.max1_x) / self.sigma) ** 2) + self.max2_y * np.exp(-((self.x - self.max2_x) / self.sigma) ** 2)

        return self.y[days_passed]
        
        
class Soil():
    
    def __init__(self, soil_type, humus_content, acidity, potassium_content, phosphorus_content, nitrogen_content):
        self.soil_type = soil_type 
        self.humus_content = humus_content
        self.acidity = acidity
        self.potassium_content = potassium_content
        self.phosphorus_content = phosphorus_content
        self.nitrogen_content = nitrogen_content

        
        
class Grazing():
    
    def __init__(self,  start_date, end_date, pasture, num_rounds=2):
        self.pasture = pasture
        self.num_rounds = num_rounds
        self.start_date = datetime.datetime.strptime(start_date, "%Y-%m-%d")
        self.end_date = datetime.datetime.strptime(end_date, "%Y-%m-%d")
        self.grazing_duration = self.end_date - self.start_date
        setattr(self.pasture, "start_date", self.start_date)
        setattr(self.pasture, "end_date", self.end_date)
        setattr(self.pasture, "grazing_duration", self.grazing_duration)
        self.preload_weather_df()
        
    def preload_weather_df(self):
        start_date = self.start_date + datetime.timedelta(-20)
        end_date = self.end_date + datetime.timedelta(+20)
        
        Hist_URL = f"https://archive-api.open-meteo.com/v1/archive?latitude={latitude}&longitude={longitude}&start_date={start_date.date()}&end_date={end_date.date()}"
        Hist_URL = apply_params_to_URL(Hist_URL, history_parameters)
        history_json_obj = make_API_request(Hist_URL)
        history_df = pd.DataFrame(history_json_obj["daily"])
        history_df.drop(columns=["weathercode", "sunrise", "sunset"], inplace=True)
        Plant.history_df = history_df
        
    def start_grazing(self):
        for day in range(self.grazing_duration.days):
            current_date = self.start_date + datetime.timedelta(days=day)
            print()
            print("Date: ", current_date.date())
            self.pasture.update_paddock_resource(current_date)
        
    
class Pasture():
    
    def __init__(self, size, paddock_masks):
        self.size = size
        self.paddock_masks = paddock_masks
        
        self.create_paddocks()
        
    def botanical_composition(self, paddock, plants_dict):
        if sum([percentage[1] for percentage in plants_dict.values()]) > 100:
            raise TypeError(f"100 < {sum([percentage[1] for percentage in plants_dict.values()])}")
            return
        setattr(self, f"paddock_{paddock}_plants", plants_dict)
    
    def set_paddock_resource(self, paddock, resource):
        setattr(self, f"paddock_{paddock}_resource", resource)
        
    def update_paddock_resource(self, grazing_day):
        for paddock, mask in enumerate(self.paddock_masks, start=1):
            plants_dict = getattr(self, f"paddock_{paddock}_plants")
            daily_forage_consumption = self.get_paddocks_daily_forage_consumption(paddock, grazing_day)
            
            daily_green_mass_delta = 0
            for plant, [obj, percentage] in plants_dict.items():
                number_of_squares = round(sum(~self.paddock_masks[paddock-1])*percentage/100)
                GI = obj.get_condition_score(grazing_day)
                SI = obj.get_seasonal_score(grazing_day)
                coeff = (GI+SI)/2; inv_coeff = 1-(GI+SI)/2
                green_mass_daily_increment = (10*10)*(coeff*obj.growth_rate/1000)*obj.plant_density; # kg
                green_mass_daily_decrement = (10*10)*(inv_coeff*obj.death_rate/1000)*obj.plant_density; # kg
                daily_green_mass_delta += (green_mass_daily_increment - green_mass_daily_decrement)
            
            paddock_resource = getattr(self, f"paddock_{paddock}_resource")
            paddock_resource = round(paddock_resource + (daily_green_mass_delta - daily_forage_consumption))
            
            print(f"Paddock #{paddock}. Resource: {paddock_resource}")
            self.set_paddock_resource(paddock, paddock_resource)
            
    
    def create_paddocks(self):
        for i, _ in enumerate(self.paddock_masks, start=1):
            setattr(self, f"paddock_{i}", [])
            
    def add_cattle_into_paddock(self, cattle, paddock_number):
        if cattle.current_paddock != paddock_number:
            if cattle.current_paddock:
                old_paddock = getattr(self, f"paddock_{cattle.current_paddock}")
                updated_old_paddock = [ocattle for ocattle in old_paddock if ocattle["object"].index != cattle.index]
                setattr(self, f"paddock_{cattle.current_paddock}", updated_old_paddock)
                
            cattle.current_paddock = paddock_number
            cattle_dict = dict();
            cattle_dict["id"] = cattle.index
            cattle_dict["object"] = cattle
            cattle_dict["paddock_number"] = cattle.current_paddock
            cattle_dict["forage_needed"] = cattle.forage_needed
            cattle_dict["already_consumed_forage"] = cattle.already_consumed_forage
            
            new_paddock = getattr(self, f"paddock_{paddock_number}")
            new_paddock.append(cattle_dict)
        else:
            print(f"{cattle} was sent to the same paddock!")
            
    def get_paddocks_daily_forage_consumption(self, paddock_number, grazing_day):
        total_forage_daily_consumption = 0
        for cattle in getattr(self, f"paddock_{paddock_number}"):
            total_forage_daily_consumption += cattle["object"].forage_needed
             
            cattle["object"].update_age((grazing_day - self.start_date).days)
            cattle["object"].update_weight()
            cattle["object"].update_forage_consumption()
        
        return total_forage_daily_consumption

# %%
pasture = Pasture(pasture_size, masks)

# %%
polyn = Plant("polyn", 7, 8, [-5, 20, 40], [0, 5, 100], [0, 20, 100], 
                 first_peak = "2023-05-11", max1_y = 0.8,
                 second_peak = "2023-08-25", max2_y = 0.5,
                 sigma = 55,
                 plant_density = 160)
typchak = Plant("typchak", 5, 6, [-5, 23, 40], [0, 7, 100], [0, 25, 100], 
                 first_peak = "2023-05-30", max1_y = 0.7,
                 second_peak = "2023-07-30", max2_y = 0.3,
                 sigma = 45,
                 plant_density = 200)
ovsyanitsa = Plant("ovsyanitsa", 10, 11, [-5, 19, 40], [0, 2, 100], [0, 15, 100], 
                 first_peak = "2023-06-08", max1_y = 0.6,
                 second_peak = "2023-08-10", max2_y = 0.4,
                 sigma = 60,
                 plant_density = 120)

# %%
pasture.botanical_composition(1, {"polyn": [polyn, 30], 
                                  "typchak": [typchak, 30], 
                                  "ovsyanitsa": [ovsyanitsa, 30],})
pasture.botanical_composition(2, {"polyn": [polyn, 80], 
                                  "typchak": [typchak, 10], 
                                  "ovsyanitsa": [ovsyanitsa, 10],})
pasture.botanical_composition(3, {"polyn": [polyn, 70], 
                                  "typchak": [typchak, 10], 
                                  "ovsyanitsa": [ovsyanitsa, 10],})
pasture.botanical_composition(4, {"polyn": [polyn, 60], 
                                  "typchak": [typchak, 30], 
                                  "ovsyanitsa": [ovsyanitsa, 10],})
pasture.botanical_composition(5, {"polyn": [polyn, 50], 
                                  "typchak": [typchak, 10], 
                                  "ovsyanitsa": [ovsyanitsa, 10],})
pasture.botanical_composition(6, {"polyn": [polyn, 40], 
                                  "typchak": [typchak, 10], 
                                  "ovsyanitsa": [ovsyanitsa, 10],})
pasture.botanical_composition(7, {"polyn": [polyn, 50], 
                                  "typchak": [typchak, 10], 
                                  "ovsyanitsa": [ovsyanitsa, 10],})

# %%
pasture.set_paddock_resource(1, 18000); pasture.set_paddock_resource(5, 17800)
pasture.set_paddock_resource(2, 18200); pasture.set_paddock_resource(6, 11500)
pasture.set_paddock_resource(3, 16500); pasture.set_paddock_resource(7, 13900)
pasture.set_paddock_resource(4, 12000);

# %%
for _ in range(60):
    cow = Cattle(random.choice(["male", "female"]), random.randint(450, 900))
    pasture.add_cattle_into_paddock(cow, 1)

# %%
grazing = Grazing("2023-05-01", "2023-08-31", pasture)

# %%
grazing.start_grazing()
# Out:
# Date:  2023-05-01
# Paddock #1. Resource: 16937
# Paddock #2. Resource: 18204
# Paddock #3. Resource: 16504
# Paddock #4. Resource: 12004
# Paddock #5. Resource: 17804
# Paddock #6. Resource: 11504
# Paddock #7. Resource: 13904
#
# Date:  2023-05-02
# Paddock #1. Resource: 15879
# Paddock #2. Resource: 18214
# Paddock #3. Resource: 16514
# Paddock #4. Resource: 12014
# Paddock #5. Resource: 17814
# Paddock #6. Resource: 11514
# Paddock #7. Resource: 13914
#
# Date:  2023-05-03
# Paddock #1. Resource: 14826
# Paddock #2. Resource: 18229
# Paddock #3. Resource: 16529
# Paddock #4. Resource: 12029
# Paddock #5. Resource: 17829
# Paddock #6. Resource: 11529
# Paddock #7. Resource: 13929
#
# Date:  2023-05-04
# Paddock #1. Resource: 13777
# Paddock #2. Resource: 18249
# Paddock #3. Resource: 16549
# Paddock #4. Resource: 12049
# Paddock #5. Resource: 17849
# Paddock #6. Resource: 11549
# Paddock #7. Resource: 13949
#
# Date:  2023-05-05
# Paddock #1. Resource: 12732
# Paddock #2. Resource: 18274
# Paddock #3. Resource: 16574
# Paddock #4. Resource: 12074
# Paddock #5. Resource: 17874
# Paddock #6. Resource: 11574
# Paddock #7. Resource: 13974
#
# Date:  2023-05-06
# Paddock #1. Resource: 11691
# Paddock #2. Resource: 18303
# Paddock #3. Resource: 16603
# Paddock #4. Resource: 12103
# Paddock #5. Resource: 17903
# Paddock #6. Resource: 11603
# Paddock #7. Resource: 14003
#
# Date:  2023-05-07
# Paddock #1. Resource: 10653
# Paddock #2. Resource: 18336
# Paddock #3. Resource: 16636
# Paddock #4. Resource: 12136
# Paddock #5. Resource: 17936
# Paddock #6. Resource: 11636
# Paddock #7. Resource: 14036
#
# Date:  2023-05-08
# Paddock #1. Resource: 9618
# Paddock #2. Resource: 18373
# Paddock #3. Resource: 16673
# Paddock #4. Resource: 12173
# Paddock #5. Resource: 17973
# Paddock #6. Resource: 11673
# Paddock #7. Resource: 14073
#
# Date:  2023-05-09
# Paddock #1. Resource: 8586
# Paddock #2. Resource: 18414
# Paddock #3. Resource: 16714
# Paddock #4. Resource: 12214
# Paddock #5. Resource: 18014
# Paddock #6. Resource: 11714
# Paddock #7. Resource: 14114
#
# Date:  2023-05-10
# Paddock #1. Resource: 7559
# Paddock #2. Resource: 18460
# Paddock #3. Resource: 16760
# Paddock #4. Resource: 12260
# Paddock #5. Resource: 18060
# Paddock #6. Resource: 11760
# Paddock #7. Resource: 14160
#
# Date:  2023-05-11
# Paddock #1. Resource: 6533
# Paddock #2. Resource: 18508
# Paddock #3. Resource: 16808
# Paddock #4. Resource: 12308
# Paddock #5. Resource: 18108
# Paddock #6. Resource: 11808
# Paddock #7. Resource: 14208
#
# Date:  2023-05-12
# Paddock #1. Resource: 5509
# Paddock #2. Resource: 18559
# Paddock #3. Resource: 16859
# Paddock #4. Resource: 12359
# Paddock #5. Resource: 18159
# Paddock #6. Resource: 11859
# Paddock #7. Resource: 14259
#
# Date:  2023-05-13
# Paddock #1. Resource: 4490
# Paddock #2. Resource: 18615
# Paddock #3. Resource: 16915
# Paddock #4. Resource: 12415
# Paddock #5. Resource: 18215
# Paddock #6. Resource: 11915
# Paddock #7. Resource: 14315
#
# Date:  2023-05-14
# Paddock #1. Resource: 3473
# Paddock #2. Resource: 18674
# Paddock #3. Resource: 16974
# Paddock #4. Resource: 12474
# Paddock #5. Resource: 18274
# Paddock #6. Resource: 11974
# Paddock #7. Resource: 14374
#
# Date:  2023-05-15
# Paddock #1. Resource: 2460
# Paddock #2. Resource: 18737
# Paddock #3. Resource: 17037
# Paddock #4. Resource: 12537
# Paddock #5. Resource: 18337
# Paddock #6. Resource: 12037
# Paddock #7. Resource: 14437
#
# Date:  2023-05-16
# Paddock #1. Resource: 1447
# Paddock #2. Resource: 18801
# Paddock #3. Resource: 17101
# Paddock #4. Resource: 12601
# Paddock #5. Resource: 18401
# Paddock #6. Resource: 12101
# Paddock #7. Resource: 14501
#
# Date:  2023-05-17
# Paddock #1. Resource: 437
# Paddock #2. Resource: 18869
# Paddock #3. Resource: 17169
# Paddock #4. Resource: 12669
# Paddock #5. Resource: 18469
# Paddock #6. Resource: 12169
# Paddock #7. Resource: 14569
#
# Date:  2023-05-18
# Paddock #1. Resource: -572
# Paddock #2. Resource: 18939
# Paddock #3. Resource: 17239
# Paddock #4. Resource: 12739
# Paddock #5. Resource: 18539
# Paddock #6. Resource: 12239
# Paddock #7. Resource: 14639
#
# Date:  2023-05-19
# Paddock #1. Resource: -1580
# Paddock #2. Resource: 19010
# Paddock #3. Resource: 17310
# Paddock #4. Resource: 12810
# Paddock #5. Resource: 18610
# Paddock #6. Resource: 12310
# Paddock #7. Resource: 14710
#
# Date:  2023-05-20
# Paddock #1. Resource: -2588
# Paddock #2. Resource: 19081
# Paddock #3. Resource: 17381
# Paddock #4. Resource: 12881
# Paddock #5. Resource: 18681
# Paddock #6. Resource: 12381
# Paddock #7. Resource: 14781
#
# Date:  2023-05-21
# Paddock #1. Resource: -3597
# Paddock #2. Resource: 19153
# Paddock #3. Resource: 17453
# Paddock #4. Resource: 12953
# Paddock #5. Resource: 18753
# Paddock #6. Resource: 12453
# Paddock #7. Resource: 14853
#
# Date:  2023-05-22
# Paddock #1. Resource: -4605
# Paddock #2. Resource: 19226
# Paddock #3. Resource: 17526
# Paddock #4. Resource: 13026
# Paddock #5. Resource: 18826
# Paddock #6. Resource: 12526
# Paddock #7. Resource: 14926
#
# Date:  2023-05-23
# Paddock #1. Resource: -5614
# Paddock #2. Resource: 19299
# Paddock #3. Resource: 17599
# Paddock #4. Resource: 13099
# Paddock #5. Resource: 18899
# Paddock #6. Resource: 12599
# Paddock #7. Resource: 14999
#
# Date:  2023-05-24
# Paddock #1. Resource: -6619
# Paddock #2. Resource: 19377
# Paddock #3. Resource: 17677
# Paddock #4. Resource: 13177
# Paddock #5. Resource: 18977
# Paddock #6. Resource: 12677
# Paddock #7. Resource: 15077
#
# Date:  2023-05-25
# Paddock #1. Resource: -7624
# Paddock #2. Resource: 19455
# Paddock #3. Resource: 17755
# Paddock #4. Resource: 13255
# Paddock #5. Resource: 19055
# Paddock #6. Resource: 12755
# Paddock #7. Resource: 15155
#
# Date:  2023-05-26
# Paddock #1. Resource: -8629
# Paddock #2. Resource: 19534
# Paddock #3. Resource: 17834
# Paddock #4. Resource: 13334
# Paddock #5. Resource: 19134
# Paddock #6. Resource: 12834
# Paddock #7. Resource: 15234
#
# Date:  2023-05-27
# Paddock #1. Resource: -9632
# Paddock #2. Resource: 19615
# Paddock #3. Resource: 17915
# Paddock #4. Resource: 13415
# Paddock #5. Resource: 19215
# Paddock #6. Resource: 12915
# Paddock #7. Resource: 15315
#
# Date:  2023-05-28
# Paddock #1. Resource: -10632
# Paddock #2. Resource: 19700
# Paddock #3. Resource: 18000
# Paddock #4. Resource: 13500
# Paddock #5. Resource: 19300
# Paddock #6. Resource: 13000
# Paddock #7. Resource: 15400
#
# Date:  2023-05-29
# Paddock #1. Resource: -11634
# Paddock #2. Resource: 19784
# Paddock #3. Resource: 18084
# Paddock #4. Resource: 13584
# Paddock #5. Resource: 19384
# Paddock #6. Resource: 13084
# Paddock #7. Resource: 15484
#
# Date:  2023-05-30
# Paddock #1. Resource: -12636
# Paddock #2. Resource: 19869
# Paddock #3. Resource: 18169
# Paddock #4. Resource: 13669
# Paddock #5. Resource: 19469
# Paddock #6. Resource: 13169
# Paddock #7. Resource: 15569
#
# Date:  2023-05-31
# Paddock #1. Resource: -13637
# Paddock #2. Resource: 19955
# Paddock #3. Resource: 18255
# Paddock #4. Resource: 13755
# Paddock #5. Resource: 19555
# Paddock #6. Resource: 13255
# Paddock #7. Resource: 15655
#
# Date:  2023-06-01
# Paddock #1. Resource: -14638
# Paddock #2. Resource: 20042
# Paddock #3. Resource: 18342
# Paddock #4. Resource: 13842
# Paddock #5. Resource: 19642
# Paddock #6. Resource: 13342
# Paddock #7. Resource: 15742
#
# Date:  2023-06-02
# Paddock #1. Resource: -15638
# Paddock #2. Resource: 20130
# Paddock #3. Resource: 18430
# Paddock #4. Resource: 13930
# Paddock #5. Resource: 19730
# Paddock #6. Resource: 13430
# Paddock #7. Resource: 15830
#
# Date:  2023-06-03
# Paddock #1. Resource: -16637
# Paddock #2. Resource: 20220
# Paddock #3. Resource: 18520
# Paddock #4. Resource: 14020
# Paddock #5. Resource: 19820
# Paddock #6. Resource: 13520
# Paddock #7. Resource: 15920
#
# Date:  2023-06-04
# Paddock #1. Resource: -17633
# Paddock #2. Resource: 20314
# Paddock #3. Resource: 18614
# Paddock #4. Resource: 14114
# Paddock #5. Resource: 19914
# Paddock #6. Resource: 13614
# Paddock #7. Resource: 16014
#
# Date:  2023-06-05
# Paddock #1. Resource: -18628
# Paddock #2. Resource: 20410
# Paddock #3. Resource: 18710
# Paddock #4. Resource: 14210
# Paddock #5. Resource: 20010
# Paddock #6. Resource: 13710
# Paddock #7. Resource: 16110
#
# Date:  2023-06-06
# Paddock #1. Resource: -19622
# Paddock #2. Resource: 20507
# Paddock #3. Resource: 18807
# Paddock #4. Resource: 14307
# Paddock #5. Resource: 20107
# Paddock #6. Resource: 13807
# Paddock #7. Resource: 16207
#
# Date:  2023-06-07
# Paddock #1. Resource: -20619
# Paddock #2. Resource: 20602
# Paddock #3. Resource: 18902
# Paddock #4. Resource: 14402
# Paddock #5. Resource: 20202
# Paddock #6. Resource: 13902
# Paddock #7. Resource: 16302
#
# Date:  2023-06-08
# Paddock #1. Resource: -21618
# Paddock #2. Resource: 20695
# Paddock #3. Resource: 18995
# Paddock #4. Resource: 14495
# Paddock #5. Resource: 20295
# Paddock #6. Resource: 13995
# Paddock #7. Resource: 16395
#
# Date:  2023-06-09
# Paddock #1. Resource: -22620
# Paddock #2. Resource: 20786
# Paddock #3. Resource: 19086
# Paddock #4. Resource: 14586
# Paddock #5. Resource: 20386
# Paddock #6. Resource: 14086
# Paddock #7. Resource: 16486
#
# Date:  2023-06-10
# Paddock #1. Resource: -23623
# Paddock #2. Resource: 20876
# Paddock #3. Resource: 19176
# Paddock #4. Resource: 14676
# Paddock #5. Resource: 20476
# Paddock #6. Resource: 14176
# Paddock #7. Resource: 16576
#
# Date:  2023-06-11
# Paddock #1. Resource: -24626
# Paddock #2. Resource: 20967
# Paddock #3. Resource: 19267
# Paddock #4. Resource: 14767
# Paddock #5. Resource: 20567
# Paddock #6. Resource: 14267
# Paddock #7. Resource: 16667
#
# Date:  2023-06-12
# Paddock #1. Resource: -25632
# Paddock #2. Resource: 21056
# Paddock #3. Resource: 19356
# Paddock #4. Resource: 14856
# Paddock #5. Resource: 20656
# Paddock #6. Resource: 14356
# Paddock #7. Resource: 16756
#
# Date:  2023-06-13
# Paddock #1. Resource: -26639
# Paddock #2. Resource: 21145
# Paddock #3. Resource: 19445
# Paddock #4. Resource: 14945
# Paddock #5. Resource: 20745
# Paddock #6. Resource: 14445
# Paddock #7. Resource: 16845
#
# Date:  2023-06-14
# Paddock #1. Resource: -27644
# Paddock #2. Resource: 21236
# Paddock #3. Resource: 19536
# Paddock #4. Resource: 15036
# Paddock #5. Resource: 20836
# Paddock #6. Resource: 14536
# Paddock #7. Resource: 16936
#
# Date:  2023-06-15
# Paddock #1. Resource: -28651
# Paddock #2. Resource: 21326
# Paddock #3. Resource: 19626
# Paddock #4. Resource: 15126
# Paddock #5. Resource: 20926
# Paddock #6. Resource: 14626
# Paddock #7. Resource: 17026
#
# Date:  2023-06-16
# Paddock #1. Resource: -29660
# Paddock #2. Resource: 21415
# Paddock #3. Resource: 19715
# Paddock #4. Resource: 15215
# Paddock #5. Resource: 21015
# Paddock #6. Resource: 14715
# Paddock #7. Resource: 17115
#
# Date:  2023-06-17
# Paddock #1. Resource: -30670
# Paddock #2. Resource: 21503
# Paddock #3. Resource: 19803
# Paddock #4. Resource: 15303
# Paddock #5. Resource: 21103
# Paddock #6. Resource: 14803
# Paddock #7. Resource: 17203
#
# Date:  2023-06-18
# Paddock #1. Resource: -31681
# Paddock #2. Resource: 21591
# Paddock #3. Resource: 19891
# Paddock #4. Resource: 15391
# Paddock #5. Resource: 21191
# Paddock #6. Resource: 14891
# Paddock #7. Resource: 17291
#
# Date:  2023-06-19
# Paddock #1. Resource: -32694
# Paddock #2. Resource: 21678
# Paddock #3. Resource: 19978
# Paddock #4. Resource: 15478
# Paddock #5. Resource: 21278
# Paddock #6. Resource: 14978
# Paddock #7. Resource: 17378
#
# Date:  2023-06-20
# Paddock #1. Resource: -33708
# Paddock #2. Resource: 21764
# Paddock #3. Resource: 20064
# Paddock #4. Resource: 15564
# Paddock #5. Resource: 21364
# Paddock #6. Resource: 15064
# Paddock #7. Resource: 17464
#
# Date:  2023-06-21
# Paddock #1. Resource: -34725
# Paddock #2. Resource: 21848
# Paddock #3. Resource: 20148
# Paddock #4. Resource: 15648
# Paddock #5. Resource: 21448
# Paddock #6. Resource: 15148
# Paddock #7. Resource: 17548
#
# Date:  2023-06-22
# Paddock #1. Resource: -35743
# Paddock #2. Resource: 21932
# Paddock #3. Resource: 20232
# Paddock #4. Resource: 15732
# Paddock #5. Resource: 21532
# Paddock #6. Resource: 15232
# Paddock #7. Resource: 17632
#
# Date:  2023-06-23
# Paddock #1. Resource: -36766
# Paddock #2. Resource: 22012
# Paddock #3. Resource: 20312
# Paddock #4. Resource: 15812
# Paddock #5. Resource: 21612
# Paddock #6. Resource: 15312
# Paddock #7. Resource: 17712
#
# Date:  2023-06-24
# Paddock #1. Resource: -37791
# Paddock #2. Resource: 22089
# Paddock #3. Resource: 20389
# Paddock #4. Resource: 15889
# Paddock #5. Resource: 21689
# Paddock #6. Resource: 15389
# Paddock #7. Resource: 17789
#
# Date:  2023-06-25
# Paddock #1. Resource: -38820
# Paddock #2. Resource: 22164
# Paddock #3. Resource: 20464
# Paddock #4. Resource: 15964
# Paddock #5. Resource: 21764
# Paddock #6. Resource: 15464
# Paddock #7. Resource: 17864
#
# Date:  2023-06-26
# Paddock #1. Resource: -39853
# Paddock #2. Resource: 22235
# Paddock #3. Resource: 20535
# Paddock #4. Resource: 16035
# Paddock #5. Resource: 21835
# Paddock #6. Resource: 15535
# Paddock #7. Resource: 17935
#
# Date:  2023-06-27
# Paddock #1. Resource: -40893
# Paddock #2. Resource: 22299
# Paddock #3. Resource: 20599
# Paddock #4. Resource: 16099
# Paddock #5. Resource: 21899
# Paddock #6. Resource: 15599
# Paddock #7. Resource: 17999
#
# Date:  2023-06-28
# Paddock #1. Resource: -41936
# Paddock #2. Resource: 22361
# Paddock #3. Resource: 20661
# Paddock #4. Resource: 16161
# Paddock #5. Resource: 21961
# Paddock #6. Resource: 15661
# Paddock #7. Resource: 18061
#
# Date:  2023-06-29
# Paddock #1. Resource: -42981
# Paddock #2. Resource: 22422
# Paddock #3. Resource: 20722
# Paddock #4. Resource: 16222
# Paddock #5. Resource: 22022
# Paddock #6. Resource: 15722
# Paddock #7. Resource: 18122
#
# Date:  2023-06-30
# Paddock #1. Resource: -44028
# Paddock #2. Resource: 22482
# Paddock #3. Resource: 20782
# Paddock #4. Resource: 16282
# Paddock #5. Resource: 22082
# Paddock #6. Resource: 15782
# Paddock #7. Resource: 18182
#
# Date:  2023-07-01
# Paddock #1. Resource: -45077
# Paddock #2. Resource: 22540
# Paddock #3. Resource: 20840
# Paddock #4. Resource: 16340
# Paddock #5. Resource: 22140
# Paddock #6. Resource: 15840
# Paddock #7. Resource: 18240
#
# Date:  2023-07-02
# Paddock #1. Resource: -46128
# Paddock #2. Resource: 22598
# Paddock #3. Resource: 20898
# Paddock #4. Resource: 16398
# Paddock #5. Resource: 22198
# Paddock #6. Resource: 15898
# Paddock #7. Resource: 18298
#
# Date:  2023-07-03
# Paddock #1. Resource: -47183
# Paddock #2. Resource: 22652
# Paddock #3. Resource: 20952
# Paddock #4. Resource: 16452
# Paddock #5. Resource: 22252
# Paddock #6. Resource: 15952
# Paddock #7. Resource: 18352
#
# Date:  2023-07-04
# Paddock #1. Resource: -48240
# Paddock #2. Resource: 22705
# Paddock #3. Resource: 21005
# Paddock #4. Resource: 16505
# Paddock #5. Resource: 22305
# Paddock #6. Resource: 16005
# Paddock #7. Resource: 18405
#
# Date:  2023-07-05
# Paddock #1. Resource: -49301
# Paddock #2. Resource: 22754
# Paddock #3. Resource: 21054
# Paddock #4. Resource: 16554
# Paddock #5. Resource: 22354
# Paddock #6. Resource: 16054
# Paddock #7. Resource: 18454
#
# Date:  2023-07-06
# Paddock #1. Resource: -50364
# Paddock #2. Resource: 22802
# Paddock #3. Resource: 21102
# Paddock #4. Resource: 16602
# Paddock #5. Resource: 22402
# Paddock #6. Resource: 16102
# Paddock #7. Resource: 18502
#
# Date:  2023-07-07
# Paddock #1. Resource: -51428
# Paddock #2. Resource: 22850
# Paddock #3. Resource: 21150
# Paddock #4. Resource: 16650
# Paddock #5. Resource: 22450
# Paddock #6. Resource: 16150
# Paddock #7. Resource: 18550
#
# Date:  2023-07-08
# Paddock #1. Resource: -52491
# Paddock #2. Resource: 22900
# Paddock #3. Resource: 21200
# Paddock #4. Resource: 16700
# Paddock #5. Resource: 22500
# Paddock #6. Resource: 16200
# Paddock #7. Resource: 18600
#
# Date:  2023-07-09
# Paddock #1. Resource: -53555
# Paddock #2. Resource: 22949
# Paddock #3. Resource: 21249
# Paddock #4. Resource: 16749
# Paddock #5. Resource: 22549
# Paddock #6. Resource: 16249
# Paddock #7. Resource: 18649
#
# Date:  2023-07-10
# Paddock #1. Resource: -54621
# Paddock #2. Resource: 22997
# Paddock #3. Resource: 21297
# Paddock #4. Resource: 16797
# Paddock #5. Resource: 22597
# Paddock #6. Resource: 16297
# Paddock #7. Resource: 18697
#
# Date:  2023-07-11
# Paddock #1. Resource: -55690
# Paddock #2. Resource: 23043
# Paddock #3. Resource: 21343
# Paddock #4. Resource: 16843
# Paddock #5. Resource: 22643
# Paddock #6. Resource: 16343
# Paddock #7. Resource: 18743
#
# Date:  2023-07-12
# Paddock #1. Resource: -56762
# Paddock #2. Resource: 23086
# Paddock #3. Resource: 21386
# Paddock #4. Resource: 16886
# Paddock #5. Resource: 22686
# Paddock #6. Resource: 16386
# Paddock #7. Resource: 18786
#
# Date:  2023-07-13
# Paddock #1. Resource: -57837
# Paddock #2. Resource: 23126
# Paddock #3. Resource: 21426
# Paddock #4. Resource: 16926
# Paddock #5. Resource: 22726
# Paddock #6. Resource: 16426
# Paddock #7. Resource: 18826
#
# Date:  2023-07-14
# Paddock #1. Resource: -58918
# Paddock #2. Resource: 23161
# Paddock #3. Resource: 21461
# Paddock #4. Resource: 16961
# Paddock #5. Resource: 22761
# Paddock #6. Resource: 16461
# Paddock #7. Resource: 18861
#
# Date:  2023-07-15
# Paddock #1. Resource: -60001
# Paddock #2. Resource: 23195
# Paddock #3. Resource: 21495
# Paddock #4. Resource: 16995
# Paddock #5. Resource: 22795
# Paddock #6. Resource: 16495
# Paddock #7. Resource: 18895
#
# Date:  2023-07-16
# Paddock #1. Resource: -61086
# Paddock #2. Resource: 23228
# Paddock #3. Resource: 21528
# Paddock #4. Resource: 17028
# Paddock #5. Resource: 22828
# Paddock #6. Resource: 16528
# Paddock #7. Resource: 18928
#
# Date:  2023-07-17
# Paddock #1. Resource: -62172
# Paddock #2. Resource: 23260
# Paddock #3. Resource: 21560
# Paddock #4. Resource: 17060
# Paddock #5. Resource: 22860
# Paddock #6. Resource: 16560
# Paddock #7. Resource: 18960
#
# Date:  2023-07-18
# Paddock #1. Resource: -63260
# Paddock #2. Resource: 23291
# Paddock #3. Resource: 21591
# Paddock #4. Resource: 17091
# Paddock #5. Resource: 22891
# Paddock #6. Resource: 16591
# Paddock #7. Resource: 18991
#
# Date:  2023-07-19
# Paddock #1. Resource: -64347
# Paddock #2. Resource: 23324
# Paddock #3. Resource: 21624
# Paddock #4. Resource: 17124
# Paddock #5. Resource: 22924
# Paddock #6. Resource: 16624
# Paddock #7. Resource: 19024
#
# Date:  2023-07-20
# Paddock #1. Resource: -65435
# Paddock #2. Resource: 23356
# Paddock #3. Resource: 21656
# Paddock #4. Resource: 17156
# Paddock #5. Resource: 22956
# Paddock #6. Resource: 16656
# Paddock #7. Resource: 19056
#
# Date:  2023-07-21
# Paddock #1. Resource: -66522
# Paddock #2. Resource: 23390
# Paddock #3. Resource: 21690
# Paddock #4. Resource: 17190
# Paddock #5. Resource: 22990
# Paddock #6. Resource: 16690
# Paddock #7. Resource: 19090
#
# Date:  2023-07-22
# Paddock #1. Resource: -67610
# Paddock #2. Resource: 23423
# Paddock #3. Resource: 21723
# Paddock #4. Resource: 17223
# Paddock #5. Resource: 23023
# Paddock #6. Resource: 16723
# Paddock #7. Resource: 19123
#
# Date:  2023-07-23
# Paddock #1. Resource: -68700
# Paddock #2. Resource: 23455
# Paddock #3. Resource: 21755
# Paddock #4. Resource: 17255
# Paddock #5. Resource: 23055
# Paddock #6. Resource: 16755
# Paddock #7. Resource: 19155
#
# Date:  2023-07-24
# Paddock #1. Resource: -69792
# Paddock #2. Resource: 23486
# Paddock #3. Resource: 21786
# Paddock #4. Resource: 17286
# Paddock #5. Resource: 23086
# Paddock #6. Resource: 16786
# Paddock #7. Resource: 19186
#
# Date:  2023-07-25
# Paddock #1. Resource: -70885
# Paddock #2. Resource: 23517
# Paddock #3. Resource: 21817
# Paddock #4. Resource: 17317
# Paddock #5. Resource: 23117
# Paddock #6. Resource: 16817
# Paddock #7. Resource: 19217
#
# Date:  2023-07-26
# Paddock #1. Resource: -71978
# Paddock #2. Resource: 23549
# Paddock #3. Resource: 21849
# Paddock #4. Resource: 17349
# Paddock #5. Resource: 23149
# Paddock #6. Resource: 16849
# Paddock #7. Resource: 19249
#
# Date:  2023-07-27
# Paddock #1. Resource: -73072
# Paddock #2. Resource: 23580
# Paddock #3. Resource: 21880
# Paddock #4. Resource: 17380
# Paddock #5. Resource: 23180
# Paddock #6. Resource: 16880
# Paddock #7. Resource: 19280
#
# Date:  2023-07-28
# Paddock #1. Resource: -74167
# Paddock #2. Resource: 23611
# Paddock #3. Resource: 21911
# Paddock #4. Resource: 17411
# Paddock #5. Resource: 23211
# Paddock #6. Resource: 16911
# Paddock #7. Resource: 19311
#
# Date:  2023-07-29
# Paddock #1. Resource: -75265
# Paddock #2. Resource: 23639
# Paddock #3. Resource: 21939
# Paddock #4. Resource: 17439
# Paddock #5. Resource: 23239
# Paddock #6. Resource: 16939
# Paddock #7. Resource: 19339
#
# Date:  2023-07-30
# Paddock #1. Resource: -76366
# Paddock #2. Resource: 23665
# Paddock #3. Resource: 21965
# Paddock #4. Resource: 17465
# Paddock #5. Resource: 23265
# Paddock #6. Resource: 16965
# Paddock #7. Resource: 19365
#
# Date:  2023-07-31
# Paddock #1. Resource: -77470
# Paddock #2. Resource: 23689
# Paddock #3. Resource: 21989
# Paddock #4. Resource: 17489
# Paddock #5. Resource: 23289
# Paddock #6. Resource: 16989
# Paddock #7. Resource: 19389
#
# Date:  2023-08-01
# Paddock #1. Resource: -78577
# Paddock #2. Resource: 23711
# Paddock #3. Resource: 22011
# Paddock #4. Resource: 17511
# Paddock #5. Resource: 23311
# Paddock #6. Resource: 17011
# Paddock #7. Resource: 19411
#
# Date:  2023-08-02
# Paddock #1. Resource: -79685
# Paddock #2. Resource: 23732
# Paddock #3. Resource: 22032
# Paddock #4. Resource: 17532
# Paddock #5. Resource: 23332
# Paddock #6. Resource: 17032
# Paddock #7. Resource: 19432
#
# Date:  2023-08-03
# Paddock #1. Resource: -80798
# Paddock #2. Resource: 23749
# Paddock #3. Resource: 22049
# Paddock #4. Resource: 17549
# Paddock #5. Resource: 23349
# Paddock #6. Resource: 17049
# Paddock #7. Resource: 19449
#
# Date:  2023-08-04
# Paddock #1. Resource: -81913
# Paddock #2. Resource: 23765
# Paddock #3. Resource: 22065
# Paddock #4. Resource: 17565
# Paddock #5. Resource: 23365
# Paddock #6. Resource: 17065
# Paddock #7. Resource: 19465
#
# Date:  2023-08-05
# Paddock #1. Resource: -83032
# Paddock #2. Resource: 23778
# Paddock #3. Resource: 22078
# Paddock #4. Resource: 17578
# Paddock #5. Resource: 23378
# Paddock #6. Resource: 17078
# Paddock #7. Resource: 19478
#
# Date:  2023-08-06
# Paddock #1. Resource: -84152
# Paddock #2. Resource: 23790
# Paddock #3. Resource: 22090
# Paddock #4. Resource: 17590
# Paddock #5. Resource: 23390
# Paddock #6. Resource: 17090
# Paddock #7. Resource: 19490
#
# Date:  2023-08-07
# Paddock #1. Resource: -85276
# Paddock #2. Resource: 23799
# Paddock #3. Resource: 22099
# Paddock #4. Resource: 17599
# Paddock #5. Resource: 23399
# Paddock #6. Resource: 17099
# Paddock #7. Resource: 19499
#
# Date:  2023-08-08
# Paddock #1. Resource: -86399
# Paddock #2. Resource: 23809
# Paddock #3. Resource: 22109
# Paddock #4. Resource: 17609
# Paddock #5. Resource: 23409
# Paddock #6. Resource: 17109
# Paddock #7. Resource: 19509
#
# Date:  2023-08-09
# Paddock #1. Resource: -87522
# Paddock #2. Resource: 23820
# Paddock #3. Resource: 22120
# Paddock #4. Resource: 17620
# Paddock #5. Resource: 23420
# Paddock #6. Resource: 17120
# Paddock #7. Resource: 19520
#
# Date:  2023-08-10
# Paddock #1. Resource: -88650
# Paddock #2. Resource: 23827
# Paddock #3. Resource: 22127
# Paddock #4. Resource: 17627
# Paddock #5. Resource: 23427
# Paddock #6. Resource: 17127
# Paddock #7. Resource: 19527
#
# Date:  2023-08-11
# Paddock #1. Resource: -89779
# Paddock #2. Resource: 23833
# Paddock #3. Resource: 22133
# Paddock #4. Resource: 17633
# Paddock #5. Resource: 23433
# Paddock #6. Resource: 17133
# Paddock #7. Resource: 19533
#
# Date:  2023-08-12
# Paddock #1. Resource: -90911
# Paddock #2. Resource: 23837
# Paddock #3. Resource: 22137
# Paddock #4. Resource: 17637
# Paddock #5. Resource: 23437
# Paddock #6. Resource: 17137
# Paddock #7. Resource: 19537
#
# Date:  2023-08-13
# Paddock #1. Resource: -92043
# Paddock #2. Resource: 23842
# Paddock #3. Resource: 22142
# Paddock #4. Resource: 17642
# Paddock #5. Resource: 23442
# Paddock #6. Resource: 17142
# Paddock #7. Resource: 19542
#
# Date:  2023-08-14
# Paddock #1. Resource: -93178
# Paddock #2. Resource: 23845
# Paddock #3. Resource: 22145
# Paddock #4. Resource: 17645
# Paddock #5. Resource: 23445
# Paddock #6. Resource: 17145
# Paddock #7. Resource: 19545
#
# Date:  2023-08-15
# Paddock #1. Resource: -94314
# Paddock #2. Resource: 23848
# Paddock #3. Resource: 22148
# Paddock #4. Resource: 17648
# Paddock #5. Resource: 23448
# Paddock #6. Resource: 17148
# Paddock #7. Resource: 19548
#
# Date:  2023-08-16
# Paddock #1. Resource: -95450
# Paddock #2. Resource: 23851
# Paddock #3. Resource: 22151
# Paddock #4. Resource: 17651
# Paddock #5. Resource: 23451
# Paddock #6. Resource: 17151
# Paddock #7. Resource: 19551
#
# Date:  2023-08-17
# Paddock #1. Resource: -96586
# Paddock #2. Resource: 23854
# Paddock #3. Resource: 22154
# Paddock #4. Resource: 17654
# Paddock #5. Resource: 23454
# Paddock #6. Resource: 17154
# Paddock #7. Resource: 19554
#
# Date:  2023-08-18
# Paddock #1. Resource: -97727
# Paddock #2. Resource: 23853
# Paddock #3. Resource: 22153
# Paddock #4. Resource: 17653
# Paddock #5. Resource: 23453
# Paddock #6. Resource: 17153
# Paddock #7. Resource: 19553
#
# Date:  2023-08-19
# Paddock #1. Resource: -98869
# Paddock #2. Resource: 23852
# Paddock #3. Resource: 22152
# Paddock #4. Resource: 17652
# Paddock #5. Resource: 23452
# Paddock #6. Resource: 17152
# Paddock #7. Resource: 19552
#
# Date:  2023-08-20
# Paddock #1. Resource: -100019
# Paddock #2. Resource: 23844
# Paddock #3. Resource: 22144
# Paddock #4. Resource: 17644
# Paddock #5. Resource: 23444
# Paddock #6. Resource: 17144
# Paddock #7. Resource: 19544
#
# Date:  2023-08-21
# Paddock #1. Resource: -101175
# Paddock #2. Resource: 23831
# Paddock #3. Resource: 22131
# Paddock #4. Resource: 17631
# Paddock #5. Resource: 23431
# Paddock #6. Resource: 17131
# Paddock #7. Resource: 19531
#
# Date:  2023-08-22
# Paddock #1. Resource: -102335
# Paddock #2. Resource: 23814
# Paddock #3. Resource: 22114
# Paddock #4. Resource: 17614
# Paddock #5. Resource: 23414
# Paddock #6. Resource: 17114
# Paddock #7. Resource: 19514
#
# Date:  2023-08-23
# Paddock #1. Resource: -103499
# Paddock #2. Resource: 23794
# Paddock #3. Resource: 22094
# Paddock #4. Resource: 17594
# Paddock #5. Resource: 23394
# Paddock #6. Resource: 17094
# Paddock #7. Resource: 19494
#
# Date:  2023-08-24
# Paddock #1. Resource: -104666
# Paddock #2. Resource: 23771
# Paddock #3. Resource: 22071
# Paddock #4. Resource: 17571
# Paddock #5. Resource: 23371
# Paddock #6. Resource: 17071
# Paddock #7. Resource: 19471
#
# Date:  2023-08-25
# Paddock #1. Resource: -105837
# Paddock #2. Resource: 23745
# Paddock #3. Resource: 22045
# Paddock #4. Resource: 17545
# Paddock #5. Resource: 23345
# Paddock #6. Resource: 17045
# Paddock #7. Resource: 19445
#
# Date:  2023-08-26
# Paddock #1. Resource: -107008
# Paddock #2. Resource: 23720
# Paddock #3. Resource: 22020
# Paddock #4. Resource: 17520
# Paddock #5. Resource: 23320
# Paddock #6. Resource: 17020
# Paddock #7. Resource: 19420
#
# Date:  2023-08-27
# Paddock #1. Resource: -108184
# Paddock #2. Resource: 23691
# Paddock #3. Resource: 21991
# Paddock #4. Resource: 17491
# Paddock #5. Resource: 23291
# Paddock #6. Resource: 16991
# Paddock #7. Resource: 19391
#
# Date:  2023-08-28
# Paddock #1. Resource: -109361
# Paddock #2. Resource: 23661
# Paddock #3. Resource: 21961
# Paddock #4. Resource: 17461
# Paddock #5. Resource: 23261
# Paddock #6. Resource: 16961
# Paddock #7. Resource: 19361
#
# Date:  2023-08-29
# Paddock #1. Resource: -110542
# Paddock #2. Resource: 23628
# Paddock #3. Resource: 21928
# Paddock #4. Resource: 17428
# Paddock #5. Resource: 23228
# Paddock #6. Resource: 16928
# Paddock #7. Resource: 19328
#
# Date:  2023-08-30
# Paddock #1. Resource: -111727
# Paddock #2. Resource: 23592
# Paddock #3. Resource: 21892
# Paddock #4. Resource: 17392
# Paddock #5. Resource: 23192
# Paddock #6. Resource: 16892
# Paddock #7. Resource: 19292

# %% [markdown]
# # Интерактивный слайдер

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import ipywidgets as widgets
# from ipywidgets import interact
# import datetime

# # Define your variables
# season_start_date_str = "2023-03-01"
# season_end_date_str = "2023-09-30"
# first_peak_date_str = "2023-04-01"
# second_peak_date_str = "2023-08-20"
# max1_y = 0.5
# max2_y = 0.2

# # Function to update and plot
# def update_plot(sigma):
#     # Convert date strings to datetime objects
#     season_start_date = datetime.datetime.strptime(season_start_date_str, "%Y-%m-%d")
#     season_end_date = datetime.datetime.strptime(season_end_date_str, "%Y-%m-%d")
#     first_peak_date = datetime.datetime.strptime(first_peak_date_str, "%Y-%m-%d")
#     second_peak_date = datetime.datetime.strptime(second_peak_date_str, "%Y-%m-%d")

#     # Calculate days from the start of the season
#     max1_x = (first_peak_date - season_start_date).days
#     max2_x = (second_peak_date - season_start_date).days

#     # Generate x values (months)
#     x = np.linspace(0, (season_end_date - season_start_date).days, 1000)

#     # Calculate the y values based on the Gaussian distribution for the two maxima
#     y = max1_y * np.exp(-((x - max1_x) / sigma) ** 2) + max2_y * np.exp(-((x - max2_x) / sigma) ** 2)

#     # Create the plot
#     plt.figure(figsize=(10, 5))
#     plt.plot(x, y, label="Коэффициент роста растении", color="green")
#     plt.xlabel("Месяц")
#     plt.ylabel("Коэффициент")
#     plt.title("Сезонный коэффициент роста растении")

#     max_y_tick = 1.0
#     plt.yticks(np.arange(0, max_y_tick + 0.1, 0.1))

#     plt.legend()
#     plt.grid(True)
#     plt.show()

# # Create an interactive slider widget for adjusting sigma
# sigma_slider = widgets.FloatSlider(value=45.5, min=1.0, max=100.0, step=1.0, description='Sigma:')

# # Use the interact function to link the slider to the update_plot function
# interact(update_plot, sigma=sigma_slider)
