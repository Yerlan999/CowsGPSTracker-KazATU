# %%
import csv, json, codecs, sys
import urllib.request
import urllib.error
import pandas as pd

# %%
Sample_URL = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/54.214106,69.519512/2022-05-01/2022-08-31?key=6M5FJJRM8RDZVFVYJGBPDTCVT"
BaseURL = 'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/'

ApiKey='6M5FJJRM8RDZVFVYJGBPDTCVT'
#UnitGroup sets the units of the output - us or metric
UnitGroup='metric'

#Location for the weather data
Location='54.214106,69.519512'

#Optional start and end dates
#If nothing is specified, the forecast is retrieved.
#If start date only is specified, a single historical or forecast day will be retrieved
#If both start and and end date are specified, a date range will be retrieved
StartDate = '2023-05-01'
EndDate='2023-08-31'

#JSON or CSV
#JSON format supports daily, hourly, current conditions, weather alerts and events in a single JSON package
#CSV format requires an 'include' parameter below to indicate which table section is required
ContentType="json"

#include sections
#values include days,hours,current,alerts
Include="days"


#basic query including location
ApiQuery=BaseURL + Location

#append the start and end date if present
if (len(StartDate)):
    ApiQuery+="/"+StartDate
    if (len(EndDate)):
        ApiQuery+="/"+EndDate

#Url is completed. Now add query parameters (could be passed as GET or POST)
ApiQuery+="?"

#append each parameter as necessary
if (len(UnitGroup)):
    ApiQuery+="&unitGroup="+UnitGroup

if (len(ContentType)):
    ApiQuery+="&contentType="+ContentType

if (len(Include)):
    ApiQuery+="&include="+Include

ApiQuery+="&key="+ApiKey

# %%
print(' - Running query URL: ', ApiQuery)
print()

try:
    # Convert from bytes to text
    resp_text = urllib.request.urlopen(ApiQuery).read().decode('UTF-8')
    # Use loads to decode from text
    json_obj = json.loads(resp_text)
    print(json_obj)
    print("JSON Object: ")

except urllib.error.HTTPError  as e:
    ErrorInfo= e.read().decode()
    print('Error code: ', e.code, ErrorInfo)
    sys.exit()
except  urllib.error.URLError as e:
    ErrorInfo= e.read().decode()
    print('Error code: ', e.code,ErrorInfo)
    sys.exit()
# Out:
#  - Running query URL:  https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/54.214106,69.519512/2022-05-01/2022-08-31?&unitGroup=metric&contentType=json&include=days&key=6M5FJJRM8RDZVFVYJGBPDTCVT
#
# CSV Text:
# <_csv.reader object at 0x000001B726688A60>
#
# {'queryCost': 123, 'latitude': 54.214106, 'longitude': 69.519512, 'resolvedAddress': '54.214106,69.519512', 'address': '54.214106,69.519512', 'timezone': 'Asia/Almaty', 'tzoffset': 6.0, 'days': [{'datetime': '2022-05-01', 'datetimeEpoch': 1651341600, 'tempmax': 10.7, 'tempmin': 3.0, 'temp': 5.9, 'feelslikemax': 10.7, 'feelslikemin': -2.1, 'feelslike': 2.0, 'dew': 0.8, 'humidity': 71.0, 'precip': 0.09, 'precipprob': 100.0, 'precipcover': 4.17, 'preciptype': ['rain'], 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 72.0, 'windspeed': 31.0, 'winddir': 44.3, 'pressure': 1012.5, 'cloudcover': 91.7, 'visibility': 17.4, 'solarradiation': 134.8, 'solarenergy': 11.6, 'uvindex': 6.0, 'severerisk': 10.0, 'sunrise': '05:45:23', 'sunriseEpoch': 1651362323, 'sunset': '20:54:01', 'sunsetEpoch': 1651416841, 'moonphase': 0.0, 'conditions': 'Rain, Overcast', 'description': 'Cloudy skies throughout the day with afternoon rain.', 'icon': 'rain', 'stations': ['28775199999', '28676099999', 'remote', '28873099999', 'UACP'], 'source': 'obs'}, {'datetime': '2022-05-02', 'datetimeEpoch': 1651428000, 'tempmax': 10.1, 'tempmin': 3.0, 'temp': 6.1, 'feelslikemax': 10.1, 'feelslikemin': -0.6, 'feelslike': 2.8, 'dew': 0.3, 'humidity': 70.3, 'precip': 1.994, 'precipprob': 100.0, 'precipcover': 4.17, 'preciptype': ['rain'], 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 61.2, 'windspeed': 36.0, 'winddir': 315.0, 'pressure': 1010.6, 'cloudcover': 66.2, 'visibility': 18.0, 'solarradiation': 223.0, 'solarenergy': 19.3, 'uvindex': 7.0, 'severerisk': 10.0, 'sunrise': '05:43:18', 'sunriseEpoch': 1651448598, 'sunset': '20:55:52', 'sunsetEpoch': 1651503352, 'moonphase': 0.05, 'conditions': 'Rain, Partially cloudy', 'description': 'Partly cloudy throughout the day with early morning rain.', 'icon': 'rain', 'stations': ['28775199999', '28676099999', 'remote', '28873099999', 'UACP'], 'source': 'obs'}, {'datetime': '2022-05-03', 'datetimeEpoch': 1651514400, 'tempmax': 14.7, 'tempmin': -4.1, 'temp': 8.1, 'feelslikemax': 14.7, 'feelslikemin': -7.8, 'feelslike': 6.9, 'dew': -6.1, 'humidity': 39.1, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': None, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 27.0, 'windspeed': 28.8, 'winddir': 277.7, 'pressure': 1018.2, 'cloudcover': 31.5, 'visibility': 18.8, 'solarradiation': 290.0, 'solarenergy': 25.0, 'uvindex': 8.0, 'severerisk': 10.0, 'sunrise': '05:41:14', 'sunriseEpoch': 1651534874, 'sunset': '20:57:43', 'sunsetEpoch': 1651589863, 'moonphase': 0.08, 'conditions': 'Partially cloudy', 'description': 'Partly cloudy throughout the day.', 'icon': 'partly-cloudy-day', 'stations': ['28775199999', '28676099999', 'remote', '28873099999', 'UACP'], 'source': 'obs'}, {'datetime': '2022-05-04', 'datetimeEpoch': 1651600800, 'tempmax': 17.1, 'tempmin': -0.1, 'temp': 11.5, 'feelslikemax': 17.1, 'feelslikemin': -3.3, 'feelslike': 10.5, 'dew': -5.7, 'humidity': 33.4, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': None, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 57.6, 'windspeed': 23.4, 'winddir': 174.8, 'pressure': 1017.3, 'cloudcover': 57.4, 'visibility': 19.6, 'solarradiation': 275.0, 'solarenergy': 23.7, 'uvindex': 7.0, 'severerisk': 10.0, 'sunrise': '05:39:12', 'sunriseEpoch': 1651621152, 'sunset': '20:59:33', 'sunsetEpoch': 1651676373, 'moonphase': 0.11, 'conditions': 'Partially cloudy', 'description': 'Becoming cloudy in the afternoon.', 'icon': 'partly-cloudy-day', 'stations': ['28775199999', '28676099999', 'remote', '28873099999', 'UACP'], 'source': 'obs'}, {'datetime': '2022-05-05', 'datetimeEpoch': 1651687200, 'tempmax': 21.0, 'tempmin': 5.9, 'temp': 14.8, 'feelslikemax': 21.0, 'feelslikemin': 4.6, 'feelslike': 14.6, 'dew': -3.2, 'humidity': 29.8, 'precip': 0.0, 'precipprob': 0.0, 'precipcover': 0.0, 'preciptype': None, 'snow': 0.0, 'snowdepth': 0.0, 'windgust': 42.8, 'windspeed': 20.9, 'winddir': 203.3, 'pressure': 1010.6, 'cloudcover': 77.8, 'visibility': 19.9, 'solarradiation': 232.1, 'solarenergy': 20.0, ' ...
# JSON Object:

# %%
df = pd.DataFrame(json_obj["days"])

# %%
df
# Out:
#        datetime  datetimeEpoch  tempmax  tempmin  temp  feelslikemax  \
# 0    2022-05-01     1651341600     10.7      3.0   5.9          10.7
# 1    2022-05-02     1651428000     10.1      3.0   6.1          10.1
# 2    2022-05-03     1651514400     14.7     -4.1   8.1          14.7
# 3    2022-05-04     1651600800     17.1     -0.1  11.5          17.1
# 4    2022-05-05     1651687200     21.0      5.9  14.8          21.0
# ..          ...            ...      ...      ...   ...           ...
# 118  2022-08-27     1661536800     20.5     11.0  17.0          20.5
# 119  2022-08-28     1661623200     22.3      4.0  13.9          22.3
# 120  2022-08-29     1661709600     28.0      7.6  19.1          27.3
# 121  2022-08-30     1661796000     29.0     13.5  21.3          27.8
# 122  2022-08-31     1661882400     30.3     13.1  22.9          28.6
#
#      feelslikemin  feelslike   dew  humidity  ...   sunrise  sunriseEpoch  \
# 0            -2.1        2.0   0.8      71.0  ...  05:45:23    1651362323
# 1            -0.6        2.8   0.3      70.3  ...  05:43:18    1651448598
# 2            -7.8        6.9  -6.1      39.1  ...  05:41:14    1651534874
# 3            -3.3       10.5  -5.7      33.4  ...  05:39:12    1651621152
# 4             4.6       14.6  -3.2      29.8  ...  05:37:12    1651707432
# ..            ...        ...   ...       ...  ...       ...           ...
# 118          11.0       17.0  11.7      72.8  ...  06:20:07    1661559607
# 119           2.2       13.6   5.8      62.8  ...  06:21:55    1661646115
# 120           6.0       18.9   8.3      51.9  ...  06:23:43    1661732623
# 121          13.5       21.1  11.0      54.6  ...  06:25:31    1661819131
# 122          13.1       22.5   9.5      45.8  ...  06:27:19    1661905639
#
#        sunset sunsetEpoch  moonphase              conditions  \
# 0    20:54:01  1651416841       0.00          Rain, Overcast
# 1    20:55:52  1651503352       0.05  Rain, Partially cloudy
# 2    20:57:43  1651589863       0.08        Partially cloudy
# 3    20:59:33  1651676373       0.11        Partially cloudy
# 4    21:01:23  1651762883       0.14        Partially cloudy
# ..        ...         ...        ...                     ...
# 118  20:25:46  1661610346       0.00  Rain, Partially cloudy
# 119  20:23:23  1661696603       0.03                    Rain
# 120  20:20:59  1661782859       0.07        Partially cloudy
# 121  20:18:35  1661869115       0.10        Partially cloudy
# 122  20:16:10  1661955370       0.14  Rain, Partially cloudy
#
#                                            description               icon  \
# 0    Cloudy skies throughout the day with afternoon...               rain
# 1    Partly cloudy throughout the day with early mo...               rain
# 2                    Partly cloudy throughout the day.  partly-cloudy-day
# 3                    Becoming cloudy in the afternoon.  partly-cloudy-day
# 4                    Partly cloudy throughout the day.  partly-cloudy-day
# ..                                                 ...                ...
# 118  Partly cloudy throughout the day with afternoo...               rain
# 119  Clear conditions throughout the day with early...               rain
# 120                  Partly cloudy throughout the day.  partly-cloudy-day
# 121                  Partly cloudy throughout the day.  partly-cloudy-day
# 122  Partly cloudy throughout the day with early mo...               rain
#
#                                               stations  source
# 0    [28775199999, 28676099999, remote, 28873099999...     obs
# 1    [28775199999, 28676099999, remote, 28873099999...     obs
# 2    [28775199999, 28676099999, remote, 28873099999...     obs
# 3    [28775199999, 28676099999, remote, 28873099999...     obs
# 4    [28775199999, 28676099999, remote, 28873099999...     obs
# ..                                                 ...     ...
# 118  [28775199999, 28676099999, remote, 28873099999...     obs
# 119  [28775199999, 28676099999, remote, 28873099999...     obs
# 120  [28775199999, 28676099999, remote, 28873099999...     obs
# 121  [28775199999, 28676099999, remote, 28873099999...     obs
# 122  [28775199999, 28676099999, remote, 28873099999...     obs
#
# [123 rows x 36 columns]

# %%
excel_file_path = f'Weather for from {StartDate} to {EndDate}.xlsx'
df.to_excel(excel_file_path, index=False)
