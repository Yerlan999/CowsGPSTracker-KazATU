# %%
import csv, json, codecs, sys
import urllib.request
import urllib.error
import pandas as pd
import requests
from pandas import json_normalize
from bs4 import BeautifulSoup

# %% [markdown]
# # Open-Meteo.com

# %% [markdown]
# # Координаты пастбища

# %%
latitude = 54.214106
longitude = 69.519512

# %% [markdown]
# # Параметры погоды

# %%
forecast_parameters = [
"temperature_2m_max",
"temperature_2m_min",
"apparent_temperature_max",
"apparent_temperature_min",
"precipitation_sum",
"rain_sum",
"showers_sum",
"snowfall_sum",
"precipitation_hours",
"precipitation_probability_max",
"precipitation_probability_min",
"precipitation_probability_mean",
"weathercode",
"sunrise",
"sunset",
"windspeed_10m_max",
"windgusts_10m_max",
"winddirection_10m_dominant",
"shortwave_radiation_sum",
"et0_fao_evapotranspiration",
"uv_index_max",
"uv_index_clear_sky_max",]

history_parameters = [
"temperature_2m_max",
"temperature_2m_min",
"apparent_temperature_max",
"apparent_temperature_min",
"precipitation_sum",
"rain_sum",
"snowfall_sum",
"precipitation_hours",
"weathercode",
"sunrise",
"sunset",
"windspeed_10m_max",
"windgusts_10m_max",
"winddirection_10m_dominant",
"shortwave_radiation_sum",
"et0_fao_evapotranspiration",]

def apply_params_to_URL(URL, parameters):
    URL += "&daily="
    for i, parameter in enumerate(parameters):
        if i < len(parameters) - 1:
            URL += parameter + ","
        else:
            URL += parameter
    URL += "&timezone=auto"
    
    print("URL updated: ", URL)
    return URL

def make_API_request(URL):
    try:
        # Convert from bytes to text
        resp_text = urllib.request.urlopen(URL).read().decode('UTF-8')
        # Use loads to decode from text
        json_obj = json.loads(resp_text)
        print("Successfull API request!")
        return json_obj
    except urllib.error.HTTPError  as e:
        ErrorInfo= e.read().decode()
        print('Error code: ', e.code, ErrorInfo)
        sys.exit()
    except  urllib.error.URLError as e:
        ErrorInfo= e.read().decode()
        print('Error code: ', e.code,ErrorInfo)
        sys.exit()
        

last_main_description = ""

def get_weather_mapping():
    global last_main_description
    
    url = "https://www.nodc.noaa.gov/archive/arc0021/0002199/1.1/data/0-data/HTML/WMO-CODE/WMO4677.HTM"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    weather_mapping = {}
    
    for i_table, table in enumerate(soup.select('table[BORDER]')):
        for i_row, row in enumerate(table.find_all('tr')[1:]):
            code_and_description = row.find_all('td')[:2]
            code = int(code_and_description[0].text.strip())
            description = code_and_description[1].text.strip()
            if not description.startswith("-"):
                last_main_description = description
            else:
                description = last_main_description
            weather_mapping[code] = description
            
            
    return weather_mapping

def weather_code_to_string(wmo_code):
    return weather_mapping.get(wmo_code, "Unknown Weather Code")

# Generate the weather mapping
weather_mapping = get_weather_mapping()

# %%
URL = f'https://api.open-meteo.com/v1/forecast?latitude={latitude}&longitude={longitude}&past_days=2'

# %%
URL = apply_params_to_URL(URL, forecast_parameters)
# Out:
# URL updated:  https://api.open-meteo.com/v1/forecast?latitude=54.214106&longitude=69.519512&past_days=2&daily=temperature_2m_max,temperature_2m_min,apparent_temperature_max,apparent_temperature_min,precipitation_sum,rain_sum,showers_sum,snowfall_sum,precipitation_hours,precipitation_probability_max,precipitation_probability_min,precipitation_probability_mean,weathercode,sunrise,sunset,windspeed_10m_max,windgusts_10m_max,winddirection_10m_dominant,shortwave_radiation_sum,et0_fao_evapotranspiration,uv_index_max,uv_index_clear_sky_max&timezone=auto

# %%
forecast_json_obj = make_API_request(URL)
# Out:
# Successfull API request!

# %% [markdown]
# # Единицы измерении значении параметров погоды

# %%
forecast_json_obj["daily_units"]
# Out:
# {'time': 'iso8601',
#  'temperature_2m_max': '°C',
#  'temperature_2m_min': '°C',
#  'apparent_temperature_max': '°C',
#  'apparent_temperature_min': '°C',
#  'precipitation_sum': 'mm',
#  'rain_sum': 'mm',
#  'showers_sum': 'mm',
#  'snowfall_sum': 'cm',
#  'precipitation_hours': 'h',
#  'precipitation_probability_max': '%',
#  'precipitation_probability_min': '%',
#  'precipitation_probability_mean': '%',
#  'weathercode': 'wmo code',
#  'sunrise': 'iso8601',
#  'sunset': 'iso8601',
#  'windspeed_10m_max': 'km/h',
#  'windgusts_10m_max': 'km/h',
#  'winddirection_10m_dominant': '°',
#  'shortwave_radiation_sum': 'MJ/m²',
#  'et0_fao_evapotranspiration': 'mm',
#  'uv_index_max': '',
#  'uv_index_clear_sky_max': ''}

# %%
forecast_json_obj["daily"]["time"]
# Out:
# ['2024-01-05',
#  '2024-01-06',
#  '2024-01-07',
#  '2024-01-08',
#  '2024-01-09',
#  '2024-01-10',
#  '2024-01-11',
#  '2024-01-12',
#  '2024-01-13']

# %% [markdown]
# # weathercode значения:
# https://www.nodc.noaa.gov/archive/arc0021/0002199/1.1/data/0-data/HTML/WMO-CODE/WMO4677.HTM

# %% [markdown]
# # Предсказание погоды на 7 дней

# %%
forecast_df = pd.DataFrame(forecast_json_obj["daily"])

# %%
forecast_df
# Out:
#          time  temperature_2m_max  temperature_2m_min  \
# 0  2024-01-05                -1.5                -8.4
# 1  2024-01-06                -9.9               -22.5
# 2  2024-01-07                -1.3               -23.3
# 3  2024-01-08                -2.3               -20.9
# 4  2024-01-09               -18.6               -23.3
# 5  2024-01-10               -16.4               -23.2
# 6  2024-01-11               -23.9               -27.3
# 7  2024-01-12               -11.0               -25.8
# 8  2024-01-13                -9.2               -22.8
#
#    apparent_temperature_max  apparent_temperature_min  precipitation_sum  \
# 0                      -7.2                     -14.8                2.8
# 1                     -16.4                     -27.2                0.0
# 2                      -6.7                     -28.3                1.3
# 3                      -6.7                     -29.2                2.1
# 4                     -24.5                     -29.7                0.0
# 5                     -21.8                     -31.7                5.1
# 6                     -32.2                     -34.4                0.0
# 7                     -18.3                     -33.6                0.2
# 8                     -15.1                     -28.8                0.7
#
#    rain_sum  showers_sum  snowfall_sum  precipitation_hours  ...  weathercode  \
# 0       0.0          0.0          1.96                  7.0  ...           73
# 1       0.0          0.0          0.00                  0.0  ...            3
# 2       0.0          0.0          0.91                  7.0  ...           71
# 3       0.0          0.0          1.47                 11.0  ...           71
# 4       0.0          0.0          0.00                  0.0  ...            3
# 5       0.0          0.0          3.57                 17.0  ...           71
# 6       0.0          0.0          0.00                  0.0  ...            2
# 7       0.0          0.0          0.14                  2.0  ...           71
# 8       0.0          0.0          0.49                  7.0  ...           71
#
#             sunrise            sunset  windspeed_10m_max windgusts_10m_max  \
# 0  2024-01-05T09:40  2024-01-05T17:13               25.3              40.7
# 1  2024-01-06T09:40  2024-01-06T17:14               21.0              33.1
# 2  2024-01-07T09:40  2024-01-07T17:15               20.6              32.8
# 3  2024-01-08T09:39  2024-01-08T17:17               32.8              53.6
# 4  2024-01-09T09:38  2024-01-09T17:18               28.4              47.2
# 5  2024-01-10T09:38  2024-01-10T17:20               31.4              52.2
# 6  2024-01-11T09:37  2024-01-11T17:21               29.3              48.6
# 7  2024-01-12T09:36  2024-01-12T17:23               37.6              63.0
# 8  2024-01-13T09:35  2024-01-13T17:24               25.5              41.8
#
#   winddirection_10m_dominant  shortwave_radiation_sum  \
# 0                        233                     1.46
# 1                        279                     3.06
# 2                        128                     1.30
# 3                        262                     2.51
# 4                        240                     3.41
# 5                        298                     1.71
# 6                        239                     3.68
# 7                        219                     2.92
# 8                        253                     2.63
#
#    et0_fao_evapotranspiration  uv_index_max  uv_index_clear_sky_max
# 0                        0.19          1.10                    1.20
# 1                        0.11          1.25                    1.25
# 2                        0.13          0.95                    1.20
# 3                        0.21          1.10                    1.20
# 4                        0.16          1.25                    1.25
# 5                        0.17          1.05                    1.25
# 6                        0.14          1.25                    1.25
# 7                        0.26          1.00                    1.20
# 8                        0.20          1.00                    1.20
#
# [9 rows x 23 columns]

# %% [markdown]
# # История погоды по заданному диапазону

# %%
start_date = "2023-05-01" 
end_date = "2023-08-31"

# %%
Hist_URL = f"https://archive-api.open-meteo.com/v1/archive?latitude={latitude}&longitude={longitude}&start_date={start_date}&end_date={end_date}"

# %%
Hist_URL = apply_params_to_URL(Hist_URL, history_parameters)
# Out:
# URL updated:  https://archive-api.open-meteo.com/v1/archive?latitude=54.214106&longitude=69.519512&start_date=2023-05-01&end_date=2023-08-31&daily=temperature_2m_max,temperature_2m_min,apparent_temperature_max,apparent_temperature_min,precipitation_sum,rain_sum,snowfall_sum,precipitation_hours,weathercode,sunrise,sunset,windspeed_10m_max,windgusts_10m_max,winddirection_10m_dominant,shortwave_radiation_sum,et0_fao_evapotranspiration&timezone=auto

# %%
history_json_obj = make_API_request(Hist_URL)
# Out:
# Successfull API request!

# %%
history_df = pd.DataFrame(history_json_obj["daily"])

# %%
history_df
# Out:
#            time  temperature_2m_max  temperature_2m_min  \
# 0    2023-05-01                13.1                 1.4
# 1    2023-05-02                14.5                -2.1
# 2    2023-05-03                18.8                -0.4
# 3    2023-05-04                22.1                 5.5
# 4    2023-05-05                23.5                 8.2
# ..          ...                 ...                 ...
# 118  2023-08-27                19.0                 8.8
# 119  2023-08-28                19.1                12.2
# 120  2023-08-29                19.5                11.8
# 121  2023-08-30                18.2                12.5
# 122  2023-08-31                15.6                10.4
#
#      apparent_temperature_max  apparent_temperature_min  precipitation_sum  \
# 0                         8.3                      -1.9                1.5
# 1                        10.8                      -6.3                0.0
# 2                        15.0                      -4.7                0.0
# 3                        18.1                       1.0                0.0
# 4                        18.5                       3.6                0.0
# ..                        ...                       ...                ...
# 118                      17.0                       7.6                0.0
# 119                      16.7                      11.1                0.8
# 120                      14.6                       8.6                1.6
# 121                      16.1                      10.0                8.0
# 122                      11.2                       7.6                0.8
#
#      rain_sum  snowfall_sum  precipitation_hours  weathercode  \
# 0         1.3          0.14                  4.0           71
# 1         0.0          0.00                  0.0            1
# 2         0.0          0.00                  0.0            2
# 3         0.0          0.00                  0.0            0
# 4         0.0          0.00                  0.0            1
# ..        ...           ...                  ...          ...
# 118       0.0          0.00                  0.0            3
# 119       0.8          0.00                  5.0           51
# 120       1.6          0.00                  4.0           53
# 121       8.0          0.00                 14.0           61
# 122       0.8          0.00                  6.0           51
#
#               sunrise            sunset  windspeed_10m_max  \
# 0    2023-05-01T05:45  2023-05-01T20:52               18.0
# 1    2023-05-02T05:43  2023-05-02T20:54               11.5
# 2    2023-05-03T05:41  2023-05-03T20:56               13.8
# 3    2023-05-04T05:39  2023-05-04T20:58               16.9
# 4    2023-05-05T05:37  2023-05-05T21:00               21.5
# ..                ...               ...                ...
# 118  2023-08-27T06:20  2023-08-27T20:26               13.4
# 119  2023-08-28T06:22  2023-08-28T20:24               13.8
# 120  2023-08-29T06:23  2023-08-29T20:22               30.8
# 121  2023-08-30T06:25  2023-08-30T20:19               27.6
# 122  2023-08-31T06:27  2023-08-31T20:17               29.1
#
#      winddirection_10m_dominant  shortwave_radiation_sum  \
# 0                             6                    24.46
# 1                            77                    24.57
# 2                           154                    24.78
# 3                           231                    24.41
# 4                           246                    25.03
# ..                          ...                      ...
# 118                          56                    15.67
# 119                         314                    11.85
# 120                         155                     7.85
# 121                         159                    10.78
# 122                         174                    13.75
#
#      et0_fao_evapotranspiration
# 0                          3.63
# 1                          3.68
# 2                          4.67
# 3                          5.72
# 4                          6.22
# ..                          ...
# 118                        2.64
# 119                        2.26
# 120                        2.85
# 121                        2.23
# 122                        2.57
#
# [123 rows x 16 columns]

# %%
history_df[history_df['time'].isin(['2023-05-04', '2023-05-05'])]
# Out:
#          time  temperature_2m_max  temperature_2m_min  \
# 3  2023-05-04                22.1                 5.5
# 4  2023-05-05                23.5                 8.2
#
#    apparent_temperature_max  apparent_temperature_min  precipitation_sum  \
# 3                      18.1                       1.0                0.0
# 4                      18.5                       3.6                0.0
#
#    rain_sum  snowfall_sum  precipitation_hours  weathercode           sunrise  \
# 3       0.0           0.0                  0.0            0  2023-05-04T05:39
# 4       0.0           0.0                  0.0            1  2023-05-05T05:37
#
#              sunset  windspeed_10m_max  winddirection_10m_dominant  \
# 3  2023-05-04T20:58               16.9                         231
# 4  2023-05-05T21:00               21.5                         246
#
#    shortwave_radiation_sum  et0_fao_evapotranspiration
# 3                    24.41                        5.72
# 4                    25.03                        6.22

# %% [markdown]
# # Open-Weather API

# %% [markdown]
# # Текущая погода

# %%
import requests

lat = str(latitude)
lon = str(longitude)
api_key = "99e5a57e01cae2c3bcbba5d43c31f645"  # Replace with your OpenWeatherMap API key

# URL template with placeholders
url_template = "https://api.openweathermap.org/data/2.5/weather?lat={}&lon={}&appid={}"

# Create the complete URL by replacing placeholders
url = url_template.format(lat, lon, api_key)

# Make the API call
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse and use the response data (assuming it's in JSON format)
    data = response.json()
    # Flatten the nested dictionaries within each element of the list
    current_weather_df = pd.concat([json_normalize(data["main"]), json_normalize(data["wind"]), pd.DataFrame({'visibility': data["visibility"]}, index=[0])], axis=1)
else:
    # Print an error message if the request was not successful
    print(f"Error: {response.status_code} - {response.text}")

# %%
current_weather_df
# Out:
#      temp  feels_like  temp_min  temp_max  pressure  humidity  sea_level  \
# 0  271.02      265.28    271.02    271.02      1005        96       1005
#
#    grnd_level  speed  deg   gust  visibility
# 0         988   5.48  160  10.59         182
